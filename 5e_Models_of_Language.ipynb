# %% [markdown]
# <a href="https://colab.research.google.com/github/Living-with-machines/dhoxss-text2tech/blob/hf/5e_Models_of_Language.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🦜 "Parrots of the Past"/ "Past Parrots" 🦜
#
# ![](https://i.giphy.com/media/v1.Y2lkPTc5MGI3NjExcnVsbDA4YWw0YWQ2ZXF3ZXQxbHc2dmJiZGU3cWhoZjJ5ZnN1cnVwaiZlcD12MV9pbnRlcm5hbF9naWZfYnlfaWQmY3Q9Zw/paRbapEqsVqyA/giphy.gif)
#
#
# Hello! This session explores the use of **language models for humanities research**. We focus on **the historical press** and demonstrate some of the tools and models we created during the **Living with Machines** project.

# %% [markdown]
# ## What else is on the menu?
#
# **Principal Questions**:
# - **What** are language models? 🤖🦜 (recap)
# - **Why** are they interesting for humanities research/history 🤷‍♀️
# - **How** to marry language models with historical data? ❤️
#
# ... 🦜 🦜and why the parrots? 🦜 🦜
#
# ![](https://i.giphy.com/media/v1.Y2lkPTc5MGI3NjExZ2xiNXdhMHg5NXp5ZHhjdHEzbGFjODNwa3c4bzR6cG00NmJqMnRzayZlcD12MV9pbnRlcm5hbF9naWZfYnlfaWQmY3Q9Zw/B8P2DKq8lKbuM/giphy.gif)
#
# ### Overview
#
# - **Intro**: What are language models?  (vewwwy short!) Why the title?
#
# - Part 1: **Language Models as Models of Language**: Experiments with historical models
#   - Language models as information compression
#   - Using LMs to investage historical pattern in language
#   - Showcase some models created during the [**Living with Machines project**](https://livingwithmachines.ac.uk/). Paper [here](https://openhumanitiesdata.metajnl.com/articles/10.5334/johd.48).
#
# - Part 2: **Language Models as Research Assistants**: Using instruction-tuned (or "chat" models) for distant reading:
#   - A chat with history?
#   - Retrieval Augmented Generation (or copy-paste).

# %% [markdown]
# # Language Models as Models of Language

# %% [markdown]
# ## What are language models?
#
# **LMs tell us what word is likely to follow a given sequence.**
#
# More technically:
#
# > “[Language models] assign a probability* to each possible next word. (Jurafsky & Martin)”
# - Given a vocabulary *V*, how likely is it that *w* (word) in *V* is follows sequence *s*?
#
# Given the sentence **“Predicting the future is hard, but not …”**
#
# - P(“impossible” | sentence) is greater than P(“aardvark” | sentence)
#
#
# > Read P(“impossible” | sentence) as the probability of observing the token “impossible” given the sequence “Predicting the future is hard, but not ...
#
#
# > Probabilities are values between 0 and 1 that sum up to 1.

# %% [markdown]
# # Modelling Language: One Token at a Time
# ## Next word prediction with GPT-2
#
# Next word prediction is the principal building block of generative AI.
#
# In the following example, we generate just one token, to follow a prompt. We will show how a language model produces a probability distribution over the vocabulary from which it can sample the next token.

# %%
# %%bash
# pip install -q -U transformers accelerate datasets shap
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.1/44.1 kB 833.5 kB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 16.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 333.2/333.2 kB 5.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 9.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 3.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 3.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 5.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 26.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 9.5 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.9.0 which is incompatible.

# %%
# import everything
from transformers import GPT2LMHeadModel, GPT2Tokenizer, GPT2Model, pipeline
import numpy as np
import shap
from torch.nn import Softmax
import pandas as pd
softmax = Softmax(dim=0) # initialize softmax function

# %%
# define a prompt
prompt = 'Hello my name is'
# prompt = 'Predicting the future is hard, but not'

# %%
# tokenizer will split a text in units the LM is built on
tokenizer = GPT2Tokenizer.from_pretrained("gpt2")
# add the EOS token as PAD token to avoid warnings
model = GPT2LMHeadModel.from_pretrained("gpt2", pad_token_id=tokenizer.eos_token_id)
# load the gpt-2 model
gpt2 = GPT2Model.from_pretrained("gpt2", pad_token_id=tokenizer.eos_token_id)
# get logits from model
predictions = model(**tokenizer(prompt, return_tensors='pt'))
# the predictions as logits
# predictions.logits.shape
# get words with highest probability
tokenizer.decode(np.argmax(predictions.logits[0,-1,:].detach().numpy()))
# order predictions
series = pd.Series(softmax(predictions.logits[0,-1,:]).detach()).sort_values(ascending=False)
# change token_ids to the actual tokens
index = [tokenizer.decode(x) for x in series.index]
# set tokens as index
series.index = index
# plot results
series[:100].plot(kind='bar',figsize=(20,5))
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1617: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be deprecated in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# <Axes: >

# %% [markdown]
# # From predicting the next token to generating complete documents
#
# To generate longer text we repeat the next token prediction multiple times until we encounter a stop symbol (or the limit of tokens to generate).
#
# Text generation involves the following steps:
#
# - Create a probability distribution over the next token
# - Sample a token based on this distribution*
# - Add the sampled token to the input sequence, and repeat...
#
#
# * we have a few tricks up our sleeves here: we can manipulate the sampling procedure using specific hyperparameters, such as `temperature`, `top_k`, `top_p`
#
# You can find a more detailed discussion on token sampling [here](https://colab.research.google.com/drive/18-2Z4TMua-nwgCpIZo0lsKL6RDxH5Bvo?usp=sharing)
#
# #### An example of temperature
# Increasing the temperature can make predictions more creative (or random if you [like](https://medium.com/mlearning-ai/softmax-temperature-5492e4007f71#:~:text=Temperature%20is%20a%20hyperparameter%20of%20LSTMs%20(and%20neural%20networks%20generally,utilize%20the%20Softmax%20decision%20layer.)))
#
# ![temperature](https://miro.medium.com/v2/resize:fit:1400/format:webp/0*7xj72SjtNHvCMQlV.jpeg)
#
# Image taken for this [blog post](https://medium.com/mlearning-ai/softmax-temperature-5492e4007f71#:~:text=Temperature%20is%20a%20hyperparameter%20of%20LSTMs%20(and%20neural%20networks%20generally,utilize%20the%20Softmax%20decision%20layer.) on temperature in Softmax.

# %% [markdown]
# The generation steps outlined above are neatly integrated in the Hugging Face 'text-generation' `pipeline`.
#
# First we instantiate the `pipeline` using the GPT2 model, the predecessor the now famous GPT3.

# %%
tokenizer_gpt2 = GPT2Tokenizer.from_pretrained("gpt2")
generator_gpt2 = pipeline('text-generation', # define the task
                     model = 'gpt2', # define the model
                     pad_token_id=tokenizer.eos_token_id # set pad_token_id
                          )
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1617: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be deprecated in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(

# %% [markdown]
# Then we have to define a prompt (or input text) for which we want to predict the next token.

# %%
# create a prompt
prompt = 'Predicting the future is hard, but not' # 'Hello, my name is'

# %% [markdown]
# Lastly, we can generate a few texts to follow the given prompt. We limit the length of these completions to 30 tokens. We use a low temperature so things won't get too weird!

# %%
# generate 3 completions of maximum 30 tokens long
completions = generator_gpt2(prompt,
            temperature=0.1, # increase temperature for more create generations
            max_length = 30,  # max length of each generated text
            num_return_sequences=3, # how many texts to generate
            truncation=True
         )
completions
# Out:
# [{'generated_text': 'Predicting the future is hard, but not impossible.\n\nThe first step is to understand the current state of the economy. The U.'},
#  {'generated_text': 'Predicting the future is hard, but not impossible.\n\nThe most important thing to remember is that the future is not a fixed time.'},
#  {'generated_text': 'Predicting the future is hard, but not impossible.\n\nThe most important thing to remember is that the future is not a fixed, fixed'}]

# %% [markdown]
# # Models ❤️ (or 🦜?) Data
#
#
#
# - **Models "mimic" or "parrot" the data they are trained on.** Some scholars argue they should be referred to as **"corpus models"** instead of "language models". See for example the [Stochastic Parrots paper](https://dl.acm.org/doi/10.1145/3442188.3445922). In this context, language models are understood to be **"compression of data"**, as their weights encode important patterns in the data. In this sense, language models can be used to investigate complex patterns and regularities in language, which I think is of interest to scholars in the digital humanities.
# - **Different training data results in different model (outputs).** We can compare models trained in different data to study how language changes over time or by context. In these scenarios, the language models themselves are valuable objects of study, especially when combined with tools/methods that allow us to **interpret** the behaviour of these models.
# - Below we have a closer look at some examples. First, we compare the vanilla GPT2 models to one fine-tuned newspaper articles from the [Heritage Made Digital collection](https://blogs.bl.uk/thenewsroom/2019/01/heritage-made-digital-the-newspapers.html), and a selection of [Queer 80s literature](https://www.london.ac.uk/about/services/senate-house-library/exhibitions/seized-books). More information about the latter is available [here](https://www.london.ac.uk/about/services/senate-house-library/exhibitions/seized-books).
#
# If you want more after this session, please consult this wonderful programming historian [tutorial](https://programminghistorian.org/en/lessons/interrogating-national-narrative-gpt))

# %% [markdown]
# # Working with Pretrained Language Models

# %% [markdown]
# Okay, let's start exploring some language models. We need to import some required tools and libraries.

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM, pipeline
import shap # we use this tool to visualize model prediction

# %% [markdown]
# ## Investigating text generations

# %% [markdown]
# **Exercise**:
#
# In the code snippet below:
# - change the `model_checkpoint` variable to load a different model
# - change to `prompt` to generate different texts
# - optional: change the `temperature` argument

# %%
# select a model
# replace gpt2 with either
# 'Kaspar/gpt-finetuned-newspapers-hmd' or 'Kaspar/QueerGPT2'
model_checkpoint = 'Kaspar/gpt-finetuned-newspapers-hmd'
# initialize the tokenizer
tokenizer_gpt2 = GPT2Tokenizer.from_pretrained(model_checkpoint)
# initialize a text generation pipeline
generator_gpt2 = pipeline('text-generation', # define the task
                     model = model_checkpoint, # define the model
                     pad_token_id=tokenizer.eos_token_id, # set pad_token_id
                     truncation=True
                          )
# writ a prompt
prompt = 'In January 1849' # 'Hello, my name is'
# generate text
completions = generator_gpt2(prompt,
            temperature=0.1, # increase temperature for more create generations
            max_length = 30,  # max length of each generated text
            num_return_sequences=3 # how many texts to generate
         )

for c in completions:
  print(c['generated_text'])
# Out:
# tokenizer_config.json:   0%|          | 0.00/640 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/798k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/21.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/237 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/3.56M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/924 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/498M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/119 [00:00<?, ?B/s]
# In January 1849, the Hon. and Learned Gentleman, in his speech on the subject of the Corn-laws, said that the Corn-laws
# In January 1849, the Rev. Mr. W. H. H. Smith, of the Royal College of Surgeons, was appointed to the
# In January 1849, the Hon. and Learned Gentleman, in his speech on the subject of the Corn-laws, said that the Corn-laws

# %% [markdown]
# ## Interpreting model predictions with shap

# %% [markdown]
# We load the different language models: `gpt2`, `QueerGPT2` and `gpt-hmd`.

# %%
explainer_dict = {}

for checkpoint in  ['gpt2','Kaspar/gpt-finetuned-newspapers-hmd','Kaspar/QueerGPT2']:
  tokenizer = AutoTokenizer.from_pretrained('gpt2', use_fast=True)
  model = AutoModelForCausalLM.from_pretrained(checkpoint)
  wrapped_model = shap.models.TopKLM(model, tokenizer, k=25)
  masker = shap.maskers.Text(tokenizer, mask_token="...", collapse_mask_token=True)
  explainer = shap.Explainer(wrapped_model, masker)
  explainer_dict[checkpoint] = explainer
# Out:
# config.json:   0%|          | 0.00/907 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/498M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/119 [00:00<?, ?B/s]

# %% [markdown]
# The `shap` library nicely visualises which parts of the input segment influence the prediction of the next token.
#
# **Exercise**
#
# Change the prompt and look at how the predictions differ in relation to the input text.

# %%
prompt = "First I went to walk the dog, then I had breakfast, now I will go to the" # change the prompt
expl = 'gpt2'
shap_values = explainer_dict[expl]([prompt])
shap.plots.text(shap_values)
# Out:
#   0%|          | 0/342 [00:00<?, ?it/s]
# PartitionExplainer explainer: 2it [00:49, 49.88s/it]
# <br>
# <hr style="height: 1px; background-color: #fff; border: none; margin-top: 18px; margin-bottom: 18px; border-top: 1px dashed #ccc;"">
# <div align="center" style="margin-top: -35px;"><div style="display: inline-block; background: #fff; padding: 5px; color: #999; font-family: monospace">[0]</div>
# </div>
#             <div align='center'>
# <script>
#     document._hover_keiregbpcfblmzpnscyy = '_tp_keiregbpcfblmzpnscyy_output_0';
#     document._zoom_keiregbpcfblmzpnscyy = undefined;
#     function _output_onclick_keiregbpcfblmzpnscyy(i) {
#         var next_id = undefined;
#
#         if (document._zoom_keiregbpcfblmzpnscyy !== undefined) {
#             document.getElementById(document._zoom_keiregbpcfblmzpnscyy+ '_zoom').style.display = 'none';
#
#             if (document._zoom_keiregbpcfblmzpnscyy === '_tp_keiregbpcfblmzpnscyy_output_' + i) {
#                 document.getElementById(document._zoom_keiregbpcfblmzpnscyy).style.display = 'block';
#                 document.getElementById(document._zoom_keiregbpcfblmzpnscyy+'_name').style.borderBottom = '3px solid #000000';
#             } else {
#                 document.getElementById(document._zoom_keiregbpcfblmzpnscyy).style.display = 'none';
#                 document.getElementById(document._zoom_keiregbpcfblmzpnscyy+'_name').style.borderBottom = 'none';
#             }
#         }
#         if (document._zoom_keiregbpcfblmzpnscyy !== '_tp_keiregbpcfblmzpnscyy_output_' + i) {
#             next_id = '_tp_keiregbpcfblmzpnscyy_output_' + i;
#             document.getElementById(next_id).style.display = 'none';
#             document.getElementById(next_id + '_zoom').style.display = 'block';
#             document.getElementById(next_id+'_name').style.borderBottom = '3px solid #000000';
#         }
#         document._zoom_keiregbpcfblmzpnscyy = next_id;
#     }
#     function _output_onmouseover_keiregbpcfblmzpnscyy(i, el) {
#         if (document._zoom_keiregbpcfblmzpnscyy !== undefined) { return; }
#         if (document._hover_keiregbpcfblmzpnscyy !== undefined) {
#             document.getElementById(document._hover_keiregbpcfblmzpnscyy + '_name').style.borderBottom = 'none';
#             document.getElementById(document._hover_keiregbpcfblmzpnscyy).style.display = 'none';
#         }
#         document.getElementById('_tp_keiregbpcfblmzpnscyy_output_' + i).style.display = 'block';
#         el.style.borderBottom = '3px solid #000000';
#         document._hover_keiregbpcfblmzpnscyy = '_tp_keiregbpcfblmzpnscyy_output_' + i;
#     }
# </script>
# <div style="color: rgb(120,120,120); font-size: 12px;">outputs</div>
# <div style="display: inline; border-bottom: 3px solid #000000; background: rgba(30.0, 136.0, 229.0, 0.5664488017429193); border-radius: 3px; padding: 0px" id="_tp_keiregbpcfblmzpnscyy_output_0_name"
#     onclick="_output_onclick_keiregbpcfblmzpnscyy(0)"
#     onmouseover="_output_onmouseover_keiregbpcfblmzpnscyy(0, this);"> park</div>
# <div style="display: inline; border-bottom: none; background: rgba(30.0, 136.0, 229.0, 0.5900970489205783); border-radius: 3px; padding: 0px" id="_tp_keiregbpcfblmzpnscyy_output_1_name"
#     onclick="_output_onclick_keiregbpcfblmzpnscyy(1)"
#     onmouseover="_output_onmouseover_keiregbpcfblmzpnscyy(1, this);"> store</div>
# <div style="display: inline; border-bottom: none; background: rgba(30.0, 136.0, 229.0, 0.6452762923351159); border-radius: 3px; padding: 0px" id="_tp_keiregbpcfblmzpnscyy_output_2_name"
#     onclick="_output_onclick_keiregbpcfblmzpnscyy(2)"
#     onmouseover="_output_onmouseover_keiregbpcfblmzpnscyy(2, this);"> gym</div>
# <div style="display: inline; border-bottom: none; background: rgba(30.0, 136.0, 229.0, 0.6610417904535552); border-radius: 3px; padding: 0px" id="_tp_keiregbpcfblmzpnscyy_output_3_name"
#     onclick="_output_onclick_keiregbpcfblmzpnscyy(3)"
#     onmouseover="_output_onmouseover_keiregbpcfblmzpnscyy(3, this);"> bathroom</div>
# <div style="display: inline; border-bottom: none; background: rgba(30.0, 136.0, 229.0, 0.6610417904535552); border-radius: 3px; padding: 0px" id="_tp_keiregbpcfblmzpnscyy_output_4_name"
#     onclick="_output_onclick_keiregbpcfblmzpnscyy(4)"
#     onmouseover="_output_onmouseover_keiregbpcfblmzpnscyy(4, this);"> vet</div>
# <div style="display: inline; border-bottom: none; background: rgba(30.0, 136.0, 229.0, 0.7241037829273124); border-radius: 3px; padding: 0px" id="_tp_keiregbpcfblmzpnscyy_output_5_name"
#     onclick="_output_onclick_keiregbpcfblmzpnscyy(5)"
#     onmouseover="_output_onmouseover_keiregbpcfblmzpnscyy(5, this);"> bar</div>
# <div style="display: inline; border-bottom: none; background: rgba(30.0, 136.0, 229.0, 0.7556347791641909); border-radius: 3px; padding: 0px" id="_tp_keiregbpcfblmzpnscyy_output_6_name"
#     onclick="_output_onclick_keiregbpcfblmzpnscyy(6)"
#     onmouseover="_output_onmouseover_keiregbpcfblmzpnscyy(6, this);"> dog</div>
# <div style="display: inline; border-bottom: none; background: rgba(30.0, 136.0, 229.0, 0.7714002772826302); border-radius: 3px; padding: 0px" id="_tp_keiregbpcfblmzpnscyy_output_7_name"
#     onclick="_output_onclick_keiregbpcfblmzpnscyy(7)"
#     onmouseover="_output_onmouseover_keiregbpcfblmzpnscyy(7, this);"> house</div>
# <div style="display: inline; border-bottom: none; background: rgba(30.0, 136.0, 229.0, 0.7714002772826302); border-radius: 3px; padding: 0px" id="_tp_keiregbpcfblmzpnscyy_output_8_name"
#     onclick="_output_onclick_keiregbpcfblmzpnscyy(8)"
#     onmouseover="_output_onmouseover_keiregbpcfblmzpnscyy(8, this);"> grocery</div>
# <div style="display: inline; border-bottom: none; background: rgba(30.0, 136.0, 229.0, 0.7792830263418499); border-radius: 3px; padding: 0px" id="_tp_keiregbpcfblmzpnscyy_output_9_name"
#     onclick="_output_onclick_keiregbpcfblmzpnscyy(9)"
#     onmouseover="_output_onmouseover_keiregbpcfblmzpnscyy(9, this);"> kitchen</div>
# <div style="display: inline; border-bottom: none; background: rgba(30.0, 136.0, 229.0, 0.7792830263418499); border-radius: 3px; padding: 0px" id="_tp_keiregbpcfblmzpnscyy_output_10_name"
#     onclick="_output_onclick_keiregbpcfblmzpnscyy(10)"
#     onmouseover="_output_onmouseover_keiregbpcfblmzpnscyy(10, this);"> restaurant</div>
# <div style="display: inline; border-bottom: none; background: rgba(30.0, 136.0, 229.0, 0.7871657754010695); border-radius: 3px; padding: 0px" id="_tp_keiregbpcfblmzpnscyy_output_11_name"
#     onclick="_output_onclick_keiregbpcfblmzpnscyy(11)"
#     onmouseover="_output_onmouseover_keiregbpcfblmzpnscyy(11, this);"> doctor</div>
# <div style="display: inline; border-bottom: none; background: rgba(30.0, 136.0, 229.0, 0.7871657754010695); border-radius: 3px; padding: 0px" id="_tp_keiregbpcfblmzpnscyy_output_12_name"
#     onclick="_output_onclick_keiregbpcfblmzpnscyy(12)"
#     onmouseover="_output_onmouseover_keiregbpcfblmzpnscyy(12, this);"> hospital</div>
# <div style="display: inline; border-bottom: none; background: rgba(30.0, 136.0, 229.0, 0.8265795206971678); border-radius: 3px; padding: 0px" id="_tp_keiregbpcfblmzpnscyy_output_13_name"
#     onclick="_output_onclick_keiregbpcfblmzpnscyy(13)"
#     onmouseover="_output_onmouseover_keiregbpcfblmzpnscyy(13, this);"> zoo</div>
# <div style="display: inline; border-bottom: none; background: rgba(30.0, 136.0, 229.0, 0.8344622697563874); border-radius: 3px; padding: 0px" id="_tp_keiregbpcfblmzpnscyy_output_14_name"
#     onclick="_output_onclick_keiregbpcfblmzpnscyy(14)"
#     onmouseover="_output_onmouseover_keiregbpcfblmzpnscyy(14, this);"> office</div>
# <div style="display: inline; border-bottom: none; background: rgba(30.0, 136.0, 229.0, 0.8738760150524857); border-radius: 3px; padding: 0px" id="_tp_keiregbpcfblmzpnscyy_output_15_name"
#     onclick="_output_onclick_keiregbpcfblmzpnscyy(15)"
#     onmouseover="_output_onmouseover_keiregbpcfblmzpnscyy(15, this);"> supermarket</div>
# <div style="display: inline; border-bottom: none; background: rgba(30.0, 136.0, 229.0, 0.9054070112893642); border-radius: 3px; padding: 0px" id="_tp_keiregbpcfblmzpnscyy_output_16_name"
#     onclick="_output_onclick_keiregbpcfblmzpnscyy(16)"
#     onmouseover

# %% [markdown]
# Importantly, if we fine-tune the model on different data, it gains novel knowledge and will change its behaviour and predictions.

# %%
prompt = "When I grow up, I want to become a" # change the prompt
expl = "gpt2" # gpt2 | Kaspar/QueerGPT2 | Kaspar/gpt-finetuned-newspapers-hmd
shap_values = explainer_dict[expl]([prompt])
shap.plots.text(shap_values)
# Out:
#   0%|          | 0/90 [00:00<?, ?it/s]
# <br>
# <hr style="height: 1px; background-color: #fff; border: none; margin-top: 18px; margin-bottom: 18px; border-top: 1px dashed #ccc;"">
# <div align="center" style="margin-top: -35px;"><div style="display: inline-block; background: #fff; padding: 5px; color: #999; font-family: monospace">[0]</div>
# </div>
#             <div align='center'>
# <script>
#     document._hover_zplpxlqocpzyhzihaomf = '_tp_zplpxlqocpzyhzihaomf_output_0';
#     document._zoom_zplpxlqocpzyhzihaomf = undefined;
#     function _output_onclick_zplpxlqocpzyhzihaomf(i) {
#         var next_id = undefined;
#
#         if (document._zoom_zplpxlqocpzyhzihaomf !== undefined) {
#             document.getElementById(document._zoom_zplpxlqocpzyhzihaomf+ '_zoom').style.display = 'none';
#
#             if (document._zoom_zplpxlqocpzyhzihaomf === '_tp_zplpxlqocpzyhzihaomf_output_' + i) {
#                 document.getElementById(document._zoom_zplpxlqocpzyhzihaomf).style.display = 'block';
#                 document.getElementById(document._zoom_zplpxlqocpzyhzihaomf+'_name').style.borderBottom = '3px solid #000000';
#             } else {
#                 document.getElementById(document._zoom_zplpxlqocpzyhzihaomf).style.display = 'none';
#                 document.getElementById(document._zoom_zplpxlqocpzyhzihaomf+'_name').style.borderBottom = 'none';
#             }
#         }
#         if (document._zoom_zplpxlqocpzyhzihaomf !== '_tp_zplpxlqocpzyhzihaomf_output_' + i) {
#             next_id = '_tp_zplpxlqocpzyhzihaomf_output_' + i;
#             document.getElementById(next_id).style.display = 'none';
#             document.getElementById(next_id + '_zoom').style.display = 'block';
#             document.getElementById(next_id+'_name').style.borderBottom = '3px solid #000000';
#         }
#         document._zoom_zplpxlqocpzyhzihaomf = next_id;
#     }
#     function _output_onmouseover_zplpxlqocpzyhzihaomf(i, el) {
#         if (document._zoom_zplpxlqocpzyhzihaomf !== undefined) { return; }
#         if (document._hover_zplpxlqocpzyhzihaomf !== undefined) {
#             document.getElementById(document._hover_zplpxlqocpzyhzihaomf + '_name').style.borderBottom = 'none';
#             document.getElementById(document._hover_zplpxlqocpzyhzihaomf).style.display = 'none';
#         }
#         document.getElementById('_tp_zplpxlqocpzyhzihaomf_output_' + i).style.display = 'block';
#         el.style.borderBottom = '3px solid #000000';
#         document._hover_zplpxlqocpzyhzihaomf = '_tp_zplpxlqocpzyhzihaomf_output_' + i;
#     }
# </script>
# <div style="color: rgb(120,120,120); font-size: 12px;">outputs</div>
# <div style="display: inline; border-bottom: 3px solid #000000; background: rgba(30.0, 136.0, 229.0, 0.7083382848088731); border-radius: 3px; padding: 0px" id="_tp_zplpxlqocpzyhzihaomf_output_0_name"
#     onclick="_output_onclick_zplpxlqocpzyhzihaomf(0)"
#     onmouseover="_output_onmouseover_zplpxlqocpzyhzihaomf(0, this);"> lawyer</div>
# <div style="display: inline; border-bottom: none; background: rgba(30.0, 136.0, 229.0, 0.7241037829273124); border-radius: 3px; padding: 0px" id="_tp_zplpxlqocpzyhzihaomf_output_1_name"
#     onclick="_output_onclick_zplpxlqocpzyhzihaomf(1)"
#     onmouseover="_output_onmouseover_zplpxlqocpzyhzihaomf(1, this);"> man</div>
# <div style="display: inline; border-bottom: none; background: rgba(30.0, 136.0, 229.0, 0.731986531986532); border-radius: 3px; padding: 0px" id="_tp_zplpxlqocpzyhzihaomf_output_2_name"
#     onclick="_output_onclick_zplpxlqocpzyhzihaomf(2)"
#     onmouseover="_output_onmouseover_zplpxlqocpzyhzihaomf(2, this);"> Christian</div>
# <div style="display: inline; border-bottom: none; background: rgba(30.0, 136.0, 229.0, 0.7556347791641909); border-radius: 3px; padding: 0px" id="_tp_zplpxlqocpzyhzihaomf_output_3_name"
#     onclick="_output_onclick_zplpxlqocpzyhzihaomf(3)"
#     onmouseover="_output_onmouseover_zplpxlqocpzyhzihaomf(3, this);"> good</div>
# <div style="display: inline; border-bottom: none; background: rgba(30.0, 136.0, 229.0, 0.7792830263418499); border-radius: 3px; padding: 0px" id="_tp_zplpxlqocpzyhzihaomf_output_4_name"
#     onclick="_output_onclick_zplpxlqocpzyhzihaomf(4)"
#     onmouseover="_output_onmouseover_zplpxlqocpzyhzihaomf(4, this);"> farmer</div>
# <div style="display: inline; border-bottom: none; background: rgba(30.0, 136.0, 229.0, 0.7871657754010695); border-radius: 3px; padding: 0px" id="_tp_zplpxlqocpzyhzihaomf_output_5_name"
#     onclick="_output_onclick_zplpxlqocpzyhzihaomf(5)"
#     onmouseover="_output_onmouseover_zplpxlqocpzyhzihaomf(5, this);"> soldier</div>
# <div style="display: inline; border-bottom: none; background: rgba(30.0, 136.0, 229.0, 0.8344622697563874); border-radius: 3px; padding: 0px" id="_tp_zplpxlqocpzyhzihaomf_output_6_name"
#     onclick="_output_onclick_zplpxlqocpzyhzihaomf(6)"
#     onmouseover="_output_onmouseover_zplpxlqocpzyhzihaomf(6, this);"> painter</div>
# <div style="display: inline; border-bottom: none; background: rgba(30.0, 136.0, 229.0, 0.8423450188156071); border-radius: 3px; padding: 0px" id="_tp_zplpxlqocpzyhzihaomf_output_7_name"
#     onclick="_output_onclick_zplpxlqocpzyhzihaomf(7)"
#     onmouseover="_output_onmouseover_zplpxlqocpzyhzihaomf(7, this);"> gentleman</div>
# <div style="display: inline; border-bottom: none; background: rgba(30.0, 136.0, 229.0, 0.865993265993266); border-radius: 3px; padding: 0px" id="_tp_zplpxlqocpzyhzihaomf_output_8_name"
#     onclick="_output_onclick_zplpxlqocpzyhzihaomf(8)"
#     onmouseover="_output_onmouseover_zplpxlqocpzyhzihaomf(8, this);"> poet</div>
# <div style="display: inline; border-bottom: none; background: rgba(30.0, 136.0, 229.0, 0.865993265993266); border-radius: 3px; padding: 0px" id="_tp_zplpxlqocpzyhzihaomf_output_9_name"
#     onclick="_output_onclick_zplpxlqocpzyhzihaomf(9)"
#     onmouseover="_output_onmouseover_zplpxlqocpzyhzihaomf(9, this);"> doctor</div>
# <div style="display: inline; border-bottom: none; background: rgba(30.0, 136.0, 229.0, 0.8738760150524857); border-radius: 3px; padding: 0px" id="_tp_zplpxlqocpzyhzihaomf_output_10_name"
#     onclick="_output_onclick_zplpxlqocpzyhzihaomf(10)"
#     onmouseover="_output_onmouseover_zplpxlqocpzyhzihaomf(10, this);"> scholar</div>
# <div style="display: inline; border-bottom: none; background: rgba(30.0, 136.0, 229.0, 0.8738760150524857); border-radius: 3px; padding: 0px" id="_tp_zplpxlqocpzyhzihaomf_output_11_name"
#     onclick="_output_onclick_zplpxlqocpzyhzihaomf(11)"
#     onmouseover="_output_onmouseover_zplpxlqocpzyhzihaomf(11, this);"> philosopher</div>
# <div style="display: inline; border-bottom: none; background: rgba(30.0, 136.0, 229.0, 0.8896415131709249); border-radius: 3px; padding: 0px" id="_tp_zplpxlqocpzyhzihaomf_output_12_name"
#     onclick="_output_onclick_zplpxlqocpzyhzihaomf(12)"
#     onmouseover="_output_onmouseover_zplpxlqocpzyhzihaomf(12, this);"> surgeon</div>
# <div style="display: inline; border-bottom: none; background: rgba(30.0, 136.0, 229.0, 0.8975242622301446); border-radius: 3px; padding: 0px" id="_tp_zplpxlqocpzyhzihaomf_output_13_name"
#     onclick="_output_onclick_zplpxlqocpzyhzihaomf(13)"
#     onmouseover="_output_onmouseover_zplpxlqocpzyhzihaomf(13, this);"> great</div>
# <div style="display: inline; border-bottom: none; background: rgba(30.0, 136.0, 229.0, 0.9054070112893642); border-radius: 3px; padding: 0px" id="_tp_zplpxlqocpzyhzihaomf_output_14_name"
#     onclick="_output_onclick_zplpxlqocpzyhzihaomf(14)"
#     onmouseover="_output_onmouseover_zplpxlqocpzyhzihaomf(14, this);"> priest</div>
# <div style="display: inline; border-bottom: none; background: rgba(30.0, 136.0, 229.0, 0.9054070112893642); border-radius: 3px; padding: 0px" id="_tp_zplpxlqocpzyhzihaomf_output_15_name"
#     onclick="_output_onclick_zplpxlqocpzyhzihaomf(15)"
#     onmouseover="_output_onmouseover_zplpxlqocpzyhzihaomf(15, this);"> sailor</div>
# <div style="display: inline; border-bottom: none; background: rgba(30.0, 136.0, 229.0, 0.9527035056446821); border-radius: 3px; padding: 0px" id="_tp_zplpxlqocpzyhzihaomf_output_16_name"
#     onclick="_output_onclick_zplpxlqocpzyhzihaomf(16)"
#     onm

# %% [markdown]
# ## Exercise

# %%
# play with the prompt and the model
prompt = "" # change the prompt
expl = "" # 'Kaspar/QueerGPT2' | gpt2 | 'Kaspar/gpt-finetuned-newspapers-hmd' |
shap_values = explainer_dict[expl]([prompt])
shap.plots.text(shap_values)

# %%
# Lastly, we can generate longer outputs and assess how these related to input tokens.
# prompt = "In January 1848, the revolution" # change the prompt
# checkpoint = 'Kaspar/gpt-finetuned-newspapers-hmd' #  choose gpt2 or Kaspar/QueerGPT2
# tokenizer = AutoTokenizer.from_pretrained('gpt2')
# model = AutoModelForCausalLM.from_pretrained(checkpoint)
# # set model decoder to true
# model.config.is_decoder = True
# # set text-generation params under task_specific_params
# model.config.task_specific_params["text-generation"] = {
#     "do_sample": True,
#     "max_length": 400,
#     "temperature": 0.2,
#     "top_k": 100,
#     #"no_repeat_ngram_size": 2,
# }
# explainer = shap.Explainer(model, tokenizer)
# shap_values = explainer([prompt])
# Out:
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   0%|          | 0/42 [00:00<?, ?it/s]
# PartitionExplainer explainer: 2it [00:10, 10.72s/it]

# %%
# shap.plots.text(shap_values)

# %% [markdown]
# # Historical Language Models

# %% [markdown]
# ## BLERT
#
# As you've noticed in the previous examples, comparing model predictions allows us to study linguistic and societal changes.
#
# **These predictions can give us insight in linguistic patterns and can be a way of investigating language at scale.**
#
# In the Living with Machines project, we investigated the concept of atypical animacy, focussed on the portrayal of machines as being 'alive'.
#
# For example:
# > "The little howling- machine had waked up !"
#
# You can read the technical paper [here](https://arxiv.org/abs/2005.11140) and the historical article [here](https://muse.jhu.edu/pub/1/article/903976/summary).
#
# (In these papers, we used a slightly different technique and type of model, namely autoencoding/masked language models (as opposed to the GPT-series which resort under the category of autoregressive/causal models).  But please ignore this distinction for now.)
#
# We masked the word 'machine' as in:
#
# > "The little howling-[MASK] had waked up !"
#
# ... and investigated what the model predicts, focussing on examples where it predicts humans or animals instead of mechanical objects.
#
# For this example, the model predicted the following for the [MASK] token.
#
# ```python
# [{'score': 0.2068408727645874,
#   'token': 3899,
#   'token_str': 'dog',
#   'sequence': 'the little howling - dog had waked up!'},
#  {'score': 0.09967557340860367,
#   'token': 4937,
#   'token_str': 'cat',
#   'sequence': 'the little howling - cat had waked up!'},
#  {'score': 0.07419851422309875,
#   'token': 4702,
#   'token_str': 'wolf',
#   'sequence': 'the little howling - wolf had waked up!'},
#  {'score': 0.05852370336651802,
#   'token': 2611,
#   'token_str': 'girl',
#   'sequence': 'the little howling - girl had waked up!'},
#  {'score': 0.03520471975207329,
#   'token': 13547,
#   'token_str': 'owl',
#   'sequence': 'the little howling - owl had waked up!'}]
# ```
#
# Moreover, we used **historical language models**, to study how these predictions change by period.
#
# We fine-tuned BLERT, a [BERT](https://huggingface.co/google-bert/bert-base-uncased) model on 19th-century BL books collections as described in [our paper](https://openhumanitiesdata.metajnl.com/articles/10.5334/johd.48).

# %%
from transformers import pipeline
sentence = "Our sewing [MASK] stood near the wall where grated windows admitted sunshine, and their hymn to Labour was the only sound that broke the brooding silence."

# %%
masker = pipeline("fill-mask", model='bert-base-uncased')
masker(sentence)

# %%
victorian_masker = pipeline("fill-mask", model='Livingwithmachines/bert_1760_1850')
victorian_masker(sentence)

# %% [markdown]
# If you are interested in BLERT trained on **all** 19th century books, you can find it here.

# %%
blert_masker = pipeline("fill-mask", model='Livingwithmachines/bert_1760_1900')
blert_masker(sentence)

# %% [markdown]
# **Exercise**
#
# Can you think of another example where we might observe interesting historical differences? Change the sentence variable with another "[MASK]" token.

# %% [markdown]
# ## Newspaper Language Models Trained with MDMA*
# *(MetaData Masking Approach).
#
#
# Usually, we train language models on just the text. We present the model with a sentences with masked tokens.
#
# > Example: "Our sewing [MASK] stood near the wall."
#
# In the process, the model learns associations between words, i.e. what words are likely to appear in which context.
#
# However, we often know quite a lot about the text that could be important for this task. For example, knowing the year when this sentences might help producing more accurate predictions:
#
# > Example: "1870 [DATE] The war between France and [MASK] took them by surprise."
#
#
# You can read the paper [here](https://arxiv.org/pdf/2211.10086).

# %% [markdown]
# ## Learning simutaneously from text and context
#
# In other words: text and context are related, what would happen if we train a model learns a relation between both? Not just predict masked token, but also what year a text was published?
#
# ERWT (Dutch for 'pea') is a series of **experimental models** trained on newspaper content and metadata (mainly year, place and politics). We used the Heritage Made Digital newspapers and the Mitchell's metadata.
#
# These are experimental models because we created them primarily for **evaluation purposes**, i.e. to undestand *how* to train these models. The remain undertrained, and unreliable, but can be used for demo-purposes as we do here.

# %%
from transformers import pipeline
erwt_masker = pipeline("fill-mask", model='Livingwithmachines/erwt-year')

# %%
erwt_masker('1820 [DATE] We received a letter from [MASK] Majesty.')

# %% [markdown]
# **Question**: What would happen if we change the year to 1850?

# %% [markdown]
# ERWT models also predict the year based on text.

# %% [markdown]
# **Exercise**
#
# Apply the `erwt_masker` to the sentences below.

# %%
'[MASK] [DATE] The Franco-Prussian war is a matter of great concern.'
'[MASK] [DATE] The Schleswig war is a matter of great concern.'

# %% [markdown]
# # Fin.
