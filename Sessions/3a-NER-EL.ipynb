# %% [markdown]
# # Named Entity Recognition and Disambiguation
#
# **Named-entity recognition (NER**) is a subtask of information extraction that seeks to locate and classify named entities mentioned in text into pre-defined categories such as person names, organizations, locations, medical codes, time expressions, quantities, monetary values, percentages, etc.
#
# **Named-entity disambiguation (NED)**, also known as named-entity linking, is the task of assigning a unique identity to entities (such as famous individuals, locations, or companies) mentioned in text.

# %% [markdown]
# ## Named entity recognition
#
# ![](images/ner.png)
#
# Ok, but how does it work?
#
# ### Rule-based approaches
#
# 1) E.g., regular expression to extract:
#
# - telephone numbers
# - e-mails
# - dates
# - prices
# - locations (e.g., word + “river” indicates a river)
#
# 2) Gazetteers: list of proper names of people, locations, organisations, etc.
#
# 3) Context patterns, such as:
# - [Person] earns [Money]
# - [PERSON] joined [ORGANIZATION]
# - [PERSON] flies to [LOCATION]
#
#
# ### Feature engineering-based Machine Learning
#
# First, you need to have (a lot of) textual data annotated with the NER tags you are interested in discovering. Then you train an algorithm that, provided with the word + additional information regarding it, for instance:
# - if it starts with a capital letter
# - if it's at the beginning of a sentence
# - if it is made by numbers and letters, etc
#
# ### Deep Learning
#
# Instead of providing the algorithm additional information that you think is relevant for the task, you provide a vector representation of each unit under study (for instance each token) and the algorithm will learn how to perform the task. We'll cover this in more details on the last day.

# %%
import spacy

#spacy.cli.download("en_core_web_sm")

# Load the large English model
nlp = spacy.load("en_core_web_sm")

def ner_text(text:str)->str:
    assert type(text) is str
    processed_text = nlp(text)
    ner = [(token.text,token.label_) for token in processed_text.ents]
    return ner

# %%
import pandas as pd

sample_blbooks_df = pd.read_pickle('data/bl_books_sample.pickle')
clean_blbooks_df = sample_blbooks_df[sample_blbooks_df['mean_wc_ocr']>0.8]
blbooks_content = clean_blbooks_df['text'].to_list()
print (len(blbooks_content))
# Out:
# 1397

# %%
for content in blbooks_content[:2]:
    # Find named entities
    ners = ner_text(content)
    print (content)
    print (ners)
    print (" ")
# Out:
# HISTORY OF ENGLAND. 8 chap, of Vezelay on the borders of Burgundy :h Philip v^^and Richard, on their arrival there, found their 1190. combined army amount to 100,000 men ;' a mighty setbJttne. force) animated with glory and religion, conducted by two warlike monarch?, provided with every thing which their several dominions could supply, and not to be overcome but by their own mis- conduct, or by the unsurmountable obstacles of nature. THE French prince and the English here re °XZ^e iterated their promises of cordial friendship, pledged their faith not to invade each other's dominions during the crusade, mutually exchanged the oaths of all their barons and prelates to the same effect, and subjected themselves to the penalty of interdicts and excommunications, if they should ever violate this public and solemn engagement. They then separated ; Philip took the road to Genoa, Richard that to Marseilles, with a view of meeting their fleets, which were severally appointed to rendezvous 14th Sept. m tnese harbours. They put to sea ; and, nearly about the same time, were obliged, by stress of weather, to take shelter in Messina, where they were detained during the whole winter. This incident laid the foundation of animosities which proved fa- tal to their enterprise. RICHARD and Philip were, by the situation and extent of their dominions, rivals in power ; by their age and inclinations, competitors for glory ; and these causes of emulation which, had the princes been employed in the field against the common enemy, might have stimulated them to martial en- terprises, soon excited, during the present leisure and repose, quarrels between monarchs of such a fiery character. Equally haughty, ambitious, in- trepid, and inflexible, they were irritated with the least appearance of injury, and were incapable, by mutual *' Hoveden, p. 660. '• Vinisauf, p. 305.
# [('8', 'CARDINAL'), ('Burgundy', 'PERSON'), ('Philip v^^and', 'ORG'), ('1190', 'DATE'), ('100,000', 'CARDINAL'), ('setbJttne', 'ORG'), ('two', 'CARDINAL'), ('French', 'NORP'), ('English', 'LANGUAGE'), ('Philip', 'PERSON'), ('Genoa', 'GPE'), ('Richard', 'PERSON'), ('Marseilles', 'PERSON'), ('14th', 'ORDINAL'), ('tnese harbours', 'PERSON'), ('Messina', 'GPE'), ('RICHARD', 'PERSON'), ('Philip', 'PERSON'), ('660', 'CARDINAL'), ('Vinisauf', 'ORG'), ('305', 'CARDINAL')]
#
# RICHARD I. 9 mutual condescensions, to efface those causes of 9 hap. complaint which unavoidably arose between them. Richard, candid, sincere, undesigning, impolitic, 1190. violent, laid himself open, on every occasion, to the designs of his antagonist ; who, provident, in terested, intriguing, failed not to take all advan tages against him : And thus, both the circum stances of their disposition in which they were simi lar, and those in which they differed, rendered it impossible for them to persevere in that harmony which was so necessary to the success of their un dertaking. The last king of Sicily and Naples was Wil- Transac liam II. who had married Joan, sister to Richard, g^'1,*' in and who, dying without issue, had bequeathed his dominions to his paternal aunt Constantia, the only legitimate descendant surviving of Roger, the first sovereign of those estates who had been honoured with the royal title. This princess had, in expec tation of that rich inheritance, been married to Henry VI. the reigning emperor;** but Tancred, her natural brother, had fixed such an interest among the barons, that, taking advantage of Henry's ab sence, he had acquired possession of the throne, and maintained his claim, by force of arms, against all the efforts of the Germans.1 The approach of the crusaders naturally gave him apprehensions for his unstable government ; and he was uncertain, whe ther he had most reason to dread the presence of the French or of the English monarch. Philip was engaged in a strict alliance with the emperor his competitor ; Richard was disgusted by his rigours towards the queen dowager, whom the Sicilian prince had confined in Palermo ; because she had opposed with all her interest his succession to the crown. Tancred, therefore, sensible of the pre sent necessity, resolved to pay court to both these formidable k Bened. Abb. p. 580. 1 Hoveden, p. 663.
# [('RICHARD I. 9', 'PERSON'), ('9', 'CARDINAL'), ('Richard', 'PERSON'), ('1190', 'DATE'), ('un', 'ORG'), ('Naples', 'GPE'), ('Transac liam II', 'PERSON'), ('Joan', 'PERSON'), ('Richard', 'PERSON'), ("g^'1", 'ORG'), ('Constantia', 'PERSON'), ('Roger', 'PERSON'), ('first', 'ORDINAL'), ('expec', 'ORG'), ('Henry VI', 'PERSON'), ('Tancred', 'PERSON'), ('Henry', 'PERSON'), ('French', 'NORP'), ('English', 'NORP'), ('Richard', 'PERSON'), ('Sicilian', 'NORP'), ('Palermo', 'GPE'), ('580', 'CARDINAL'), ('1', 'CARDINAL'), ('663', 'CARDINAL')]

# %% [markdown]
# ✏️ **Exercise:**
#
# Write a programme that given a string of text it finds the named entities (like `ner_text`) but returns the original text with the identified entities replaced by (string, ner_tag). For instance:
#
# input: "New York is a big city"
#
# output: "(New York, GPE) is a big city"

# %% [markdown]
# ## Entity Linking

# %%
import spacy,spacyfishing

text_en = "Victor Hugo and Honoré de Balzac are French writers who lived in Paris."

nlp_model_en = spacy.load("en_core_web_sm")

nlp_model_en.add_pipe("entityfishing")

doc_en = nlp_model_en(text_en)

for ent in doc_en.ents:
        print((ent.text, ent.label_, ent._.kb_qid, ent._.url_wikidata, ent._.nerd_score))
# Out:
# ('Victor Hugo', 'PERSON', 'Q535', 'https://www.wikidata.org/wiki/Q535', 0.972)
# ('Honoré de Balzac', 'PERSON', 'Q9711', 'https://www.wikidata.org/wiki/Q9711', 0.9724)
# ('French', 'NORP', 'Q121842', 'https://www.wikidata.org/wiki/Q121842', 0.3739)
# ('Paris', 'GPE', 'Q90', 'https://www.wikidata.org/wiki/Q90', 0.5652)

# %%
for content in blbooks_content[:10]:
    doc_en = nlp_model_en(content)
    for ent in doc_en.ents:
            print((ent.text, ent.label_, ent._.kb_qid, ent._.url_wikidata, ent._.nerd_score))
# Out:
# ('8', 'CARDINAL', 'Q5349142', 'https://www.wikidata.org/wiki/Q5349142', 0.0826)
# ('Burgundy', 'PERSON', 'Q1173', 'https://www.wikidata.org/wiki/Q1173', 0.1795)
# ('Philip v^^and', 'ORG', None, None, None)
# ('1190', 'DATE', 'Q19736', 'https://www.wikidata.org/wiki/Q19736', 0.0889)
# ('100,000', 'CARDINAL', 'Q720751', 'https://www.wikidata.org/wiki/Q720751', 0.1341)
# ('setbJttne', 'ORG', None, None, None)
# ('two', 'CARDINAL', 'Q200', 'https://www.wikidata.org/wiki/Q200', 0.0826)
# ('French', 'NORP', 'Q142', 'https://www.wikidata.org/wiki/Q142', 0.1047)
# ('English', 'LANGUAGE', 'Q1860', 'https://www.wikidata.org/wiki/Q1860', 0.1033)
# ('Philip', 'PERSON', 'Q43675', 'https://www.wikidata.org/wiki/Q43675', 0.0826)
# ('Genoa', 'GPE', 'Q1449', 'https://www.wikidata.org/wiki/Q1449', 0.2786)
# ('Richard', 'PERSON', None, None, None)
# ('Marseilles', 'PERSON', 'Q23482', 'https://www.wikidata.org/wiki/Q23482', 0.3798)
# ('14th', 'ORDINAL', 'Q188116', 'https://www.wikidata.org/wiki/Q188116', 0.0826)
# ('tnese harbours', 'PERSON', None, None, None)
# ('Messina', 'GPE', 'Q13666', 'https://www.wikidata.org/wiki/Q13666', 0.2566)
# ('RICHARD', 'PERSON', None, None, None)
# ('Philip', 'PERSON', 'Q43675', 'https://www.wikidata.org/wiki/Q43675', 0.0826)
# ('660', 'CARDINAL', 'Q1490334', 'https://www.wikidata.org/wiki/Q1490334', 0.0827)
# ('Vinisauf', 'ORG', None, None, None)
# ('305', 'CARDINAL', 'Q3150333', 'https://www.wikidata.org/wiki/Q3150333', 0.0826)
# ('RICHARD I. 9', 'PERSON', None, None, None)
# ('9', 'CARDINAL', 'Q7039258', 'https://www.wikidata.org/wiki/Q7039258', 0.0826)
# ('Richard', 'PERSON', None, None, None)
# ('1190', 'DATE', 'Q19736', 'https://www.wikidata.org/wiki/Q19736', 0.0889)
# ('un', 'ORG', 'Q1065', 'https://www.wikidata.org/wiki/Q1065', 0.1521)
# ('Naples', 'GPE', 'Q2634', 'https://www.wikidata.org/wiki/Q2634', 0.3679)
# ('Transac liam II', 'PERSON', None, None, None)
# ('Joan', 'PERSON', 'Q1091368', 'https://www.wikidata.org/wiki/Q1091368', 0.0826)
# ('Richard', 'PERSON', None, None, None)
# ("g^'1", 'ORG', None, None, None)
# ('Constantia', 'PERSON', 'Q1127739', 'https://www.wikidata.org/wiki/Q1127739', 0.1352)
# ('Roger', 'PERSON', 'Q1061673', 'https://www.wikidata.org/wiki/Q1061673', 0.0826)
# ('first', 'ORDINAL', None, None, None)
# ('expec', 'ORG', None, None, None)
# ('Henry VI', 'PERSON', 'Q160337', 'https://www.wikidata.org/wiki/Q160337', 0.6616)
# ('Tancred', 'PERSON', 'Q51720', 'https://www.wikidata.org/wiki/Q51720', 0.1179)
# ('Henry', 'PERSON', None, None, None)
# ('French', 'NORP', 'Q142', 'https://www.wikidata.org/wiki/Q142', 0.1047)
# ('English', 'NORP', 'Q1860', 'https://www.wikidata.org/wiki/Q1860', 0.1033)
# ('Richard', 'PERSON', None, None, None)
# ('Sicilian', 'NORP', 'Q1460', 'https://www.wikidata.org/wiki/Q1460', 0.2098)
# ('Palermo', 'GPE', 'Q2656', 'https://www.wikidata.org/wiki/Q2656', 0.2739)
# ('580', 'CARDINAL', 'Q376835', 'https://www.wikidata.org/wiki/Q376835', 0.0827)
# ('1', 'CARDINAL', 'Q199', 'https://www.wikidata.org/wiki/Q199', 0.0826)
# ('663', 'CARDINAL', 'Q31122', 'https://www.wikidata.org/wiki/Q31122', 0.0827)
# ('10', 'CARDINAL', 'Q184591', 'https://www.wikidata.org/wiki/Q184591', 0.0826)
# ('nis', 'ORG', 'Q11732523', 'https://www.wikidata.org/wiki/Q11732523', 0.0976)
# ('ii9o', 'FAC', None, None, None)
# ('Christian', 'NORP', 'Q106039', 'https://www.wikidata.org/wiki/Q106039', 0.111)
# ('Joan', 'PERSON', 'Q1091368', 'https://www.wikidata.org/wiki/Q1091368', 0.0826)
# ('Richard', 'PERSON', None, None, None)
# ('Arthur', 'ORG', 'Q1056342', 'https://www.wikidata.org/wiki/Q1056342', 0.0826)
# ('Britany', 'ORG', 'Q327', 'https://www.wikidata.org/wiki/Q327', 0.4096)
# ('Richard', 'PERSON', None, None, None)
# ('Tancred', 'PERSON', 'Q468653', 'https://www.wikidata.org/wiki/Q468653', 0.4334)
# ('Messina', 'GPE', 'Q13666', 'https://www.wikidata.org/wiki/Q13666', 0.5289)
# ('English', 'NORP', 'Q1860', 'https://www.wikidata.org/wiki/Q1860', 0.1033)
# ('Richard', 'PERSON', None, None, None)
# ('two', 'CARDINAL', 'Q200', 'https://www.wikidata.org/wiki/Q200', 0.0826)
# ('Sicilians', 'NORP', 'Q188586', 'https://www.wikidata.org/wiki/Q188586', 0.3838)
# ('Richard', 'PERSON', None, None, None)
# ('English', 'LANGUAGE', 'Q1860', 'https://www.wikidata.org/wiki/Q1860', 0.1033)
# ('Messinese', 'NORP', 'Q29390', 'https://www.wikidata.org/wiki/Q29390', 0.1513)
# ('England', 'GPE', 'Q21', 'https://www.wikidata.org/wiki/Q21', 0.2171)
# ('Richard', 'PERSON', None, None, None)
# ('■ Hoveden', 'PERSON', None, None, None)
# ('676', 'CARDINAL', 'Q6870805', 'https://www.wikidata.org/wiki/Q6870805', 0.0827)
# ('677', 'CARDINAL', 'Q6870807', 'https://www.wikidata.org/wiki/Q6870807', 0.0827)
# ('61 5', 'CARDINAL', None, None, None)
# ('608', 'CARDINAL', 'Q2342387', 'https://www.wikidata.org/wiki/Q2342387', 0.0827)
# ('RICHARD I. 11 CHAP X. \\0~<**/', 'PERSON', None, None, None)
# ('1190', 'DATE', 'Q19736', 'https://www.wikidata.org/wiki/Q19736', 0.0889)
# ('1191', 'DATE', 'Q4575781', 'https://www.wikidata.org/wiki/Q4575781', 0.2896)
# ('French', 'NORP', 'Q142', 'https://www.wikidata.org/wiki/Q142', 0.1047)
# ('two', 'CARDINAL', 'Q200', 'https://www.wikidata.org/wiki/Q200', 0.0826)
# ('Richard', 'PERSON', None, None, None)
# ('French', 'NORP', 'Q142', 'https://www.wikidata.org/wiki/Q142', 0.1047)
# ('Burgundy', 'PERSON', 'Q1173', 'https://www.wikidata.org/wiki/Q1173', 0.4895)
# ('English', 'LANGUAGE', 'Q1860', 'https://www.wikidata.org/wiki/Q1860', 0.1033)
# ('un', 'ORG', 'Q1065', 'https://www.wikidata.org/wiki/Q1065', 0.1521)
# ('Richard', 'PERSON', None, None, None)
# ('Philip', 'ORG', 'Q43675', 'https://www.wikidata.org/wiki/Q43675', 0.0826)
# ('Si', 'NORP', 'Q670', 'https://www.wikidata.org/wiki/Q670', 0.0891)
# ('Richard', 'PERSON', None, None, None)
# ('Richard', 'PERSON', None, None, None)
# ('Alice', 'PERSON', 'Q1248019', 'https://www.wikidata.org/wiki/Q1248019', 0.0826)
# ('France', 'GPE', 'Q142', 'https://www.wikidata.org/wiki/Q142', 0.3523)
# ('Hoveden', 'PERSON', 'Q1231843', 'https://www.wikidata.org/wiki/Q1231843', 0.3471)
# ('674', 'CARDINAL', 'Q2269485', 'https://www.wikidata.org/wiki/Q2269485', 0.0827)
# ('688', 'CARDINAL', 'Q6870825', 'https://www.wikidata.org/wiki/Q6870825', 0.0827)
# ('642', 'CARDINAL', 'Q30872', 'https://www.wikidata.org/wiki/Q30872', 0.0827)
# ('643', 'CARDINAL', 'Q31634', 'https://www.wikidata.org/wiki/Q31634', 0.0827)
# ('Brompton', 'GPE', 'Q2926028', 'https://www.wikidata.org/wiki/Q2926028', 0.1008)
# ('1195', 'CARDINAL', 'Q19745', 'https://www.wikidata.org/wiki/Q19745', 0.0923)
# ('14', 'CARDINAL', 'Q407638', 'https://www.wikidata.org/wiki/Q407638', 0.0826)
# ('1191', 'DATE', 'Q19738', 'https://www.wikidata.org/wiki/Q19738', 0.0897)
# ('State of Palestine', 'ORG', 'Q219060', 'https://www.wikidata.org/wiki/Q219060', 0.9678)
# ('French', 'NORP', 'Q142', 'https://www.wikidata.org/wiki/Q142', 0.1047)
# ('English', 'LANGUAGE', 'Q1860', 'https://www.wikidata.org/wiki/Q1860', 0.1033)
# ('Next day', 'DATE', 'Q1304163', 'https://www.wikidata.org/wiki/Q1304163', 0.4166)
# ('English', 'NORP', 'Q1860', 'https://www.wikidata.org/wiki/Q1860', 0.1033)
# ('French', 'NORP', 'Q142', 'https://www.wikidata.org/wiki/Q142', 0.1047)
# ('Richard', 'PERSON', None, None, None)
# ('Bouillon', 'ORG', 'Q217216', 'https://www.wikidata.org/wiki/Q217216', 0.113)
# ('first', 'ORDINAL', None, None, None)
# ('Jerusalem', 'GPE', 'Q1218', 'https://www.wikidata.org/wiki/Q1218', 0.3635)
# ('Fulk', 'PERSON', 'Q528014', 'https://www.wikidata.org/wiki/Q528014', 0.0956)
# ('Henry II', 'PERSON', 'Q102140', 'https://www.wikidata.org/wiki/Q102140', 0.8489)
# ('England', 'GPE', 'Q21', 'https://www.wikidata.org/wiki/Q21', 0.2171)
# ('Anjevin', 'PERSON', None, None, None)
# ('Guy de Lusignan', 'PERSON', 'Q294192', 'https://www.wikidata.org/wiki/Q294192', 0.9627)
# ('Sibylla', 'ORG', 'Q234782', 'https://www.wikidata.org/wiki/Q234782', 0.3632)
# ('Chris', 'PERSON', 'Q925989', 'https://www.wikidata.org/wiki/Q925989', 0.0826)
# ('Sibylla', 'PERSON', 'Q234782', 'https://www.wikidata.org/wiki/Q234782', 0.3632)
# ('Acre', 'GPE', 'Q126084', 'https://www.wikidata.org/wiki/Q126084', 0.5084)
# ('Isabella', 'PERSON', 'Q45859', 'https://www.wikidata.org/wiki/Q45859', 0.0888)
# ('Lusignan', 'GPE', 'Q378193', 'https://www.wikidata.org/wiki/Q378193', 0.4377)
# ('Conrade', 'PERSON', 'Q169329', 'https://www.wikidata.org/wiki/Q169329', 0.3752)
# ('Mont', 'ORG', 'Q179923', 'https://www.wikidata.org/wiki/Q179923', 0.0826)
# ('Lusignan', 'GPE', 'Q378193', 'https://www.wikidata.org/wiki/Q378193', 0.4377)
# ('Richard', 'PERSON', None, None, None)
# ('Conrade', 'PERSON', 'Q169329', 'https://www.wikidata.org/wiki/Q169329', 0.3752)
# ('1', 'CARDINAL', 'Q199', 'https://www.wikidata.org/wiki/Q199', 0.0826)
# ('Vinisauf', 'ORG', None, None, None)
# ('281', 'CARDINAL', 'Q2175059', 'https://www.wikidata.org/wiki/Q2175059', 0.0826)
# ('134', 'CARDINAL', 'Q6669940', 'https://www.wikidata.org/wiki/Q6669940', 0.0826)
# ('Vmisauf', 'ORG', None, None, None)
# ('342', 'CARDINAL', 'Q421126', 'https://www.wikidata.org/wiki/Q421126', 0.0827)
# ('W. Heming', 'PERSON', None, None, None)
# ('624', 'CARDINAL', 'Q33247', 'https://www.wikidata.org/wiki/Q33247', 0.0827)
# ('RICHARD I. 17', 'PERSON', None, None, None)
# ('Walter 1191', 'PERSON', None, None, None)
# ('Rouen', 'GPE', 'Q30974', 'https://www.wikidata.org/wiki/Q30974', 0.6261)
# ('William Marshal', 'PERSON', 'Q348911', 'https://www.wikidata.org/wiki/Q348911', 0.9582)
# ('Strigul', 'ORG', None, None, None)
# ('Geoffrey Fitz-Peter', 'PERSON', None, None, None)
# ('William Briewere', 'PERSON', 'Q3568456', 'https://www.wikidata.org/wiki/Q3568456', 0.9629)
# ('Hugh Bardolf', 'PERSON', 'Q5929948', 'https://www.wikidata.org/wiki/Q5929948', 0.9258)
# ('Longchamp', 'ORG', 'Q1542489', 'https://www.wikidata.org/wiki/Q1542489', 0.2447)
# ('Rouen', 'GPE', 'Q30974', 'https://www.wikidata.org/wiki/Q30974', 0.6261)
# ('Strigul', 'PERSON', None, None, None)
# ('Longchamp', 'ORG', 'Q1542489', 'https://www.wikidata.org/wiki/Q1542489', 0.2447)
# ('Geoffrey', 'PERSON', 'Q314550', 'https://www.wikidata.org/wiki/Q314550', 0.0826)
# ('York', 'ORG', 'Q42462', 'https://www.wikidata.org/wiki/Q42462', 0.0885)
# ('Longchamp', 'ORG', 'Q1542489', 'https://www.wikidata.org/wiki/Q1542489', 0.2447)
# ('Reading', 'GPE', 'Q18729', 'https://www.wikidata.org/wiki/Q18729', 0.1204)
# ('the Tower of Lon don', 'FAC', None, None, None)
# ('chan cellor', 'ORG', None, None, None)
# ('Rouen', 'ORG', 'Q30974', 'https://www.wikidata.org/wiki/Q30974', 0.6261)
# ('Celestine', 'PERSON', 'Q1093546', 'https://www.wikidata.org/wiki/Q1093546', 0.0926)
# ('Philip', 'ORG', 'Q43675', 'https://www.wikidata.org/wiki/Q43675', 0.0826)
# ('Richard', 'PERSON', None, None, None)
# ('first', 'ORDINAL', None, None, None)
# ('Normandy', 'PERSON', 'Q18677875', 'https://www.wikidata.org/wiki/Q18677875', 0.3709)
# ('French', 'NORP', 'Q142', 'https://www.wikidata.org/wiki/Q142', 0.1047)
# ('18', 'CARDINAL', None, None, None)
# ('England', 'GPE', None, None, None)
# ('Richard', 'PERSON', None, None, None)
# ('Eleanor', 'PERSON', None, None, None)
# ('English', 'NORP', None, None, None)
# ('Palestine', 'GPE', None, None, None)
# ('East', 'LOC', None, None, None)
# ('England', 'GPE', None, None, None)
# ('Asia', 'LOC', None, None, None)
# ('e W. Heming', 'PERSON', None, None, None)
# ('532', 'CARDINAL', None, None, None)
# ('Brompton', 'GPE', None, None, None)
# ('1243', 'DATE', None, None, None)
# ('RICHARD I. 19', 'PERSON', None, None, None)
# ('Assassins', 'LOC', 'Q2259133', 'https://www.wikidata.org/wiki/Q2259133', 0.1091)
# ('Conrade', 'PERSON', 'Q130851', 'https://www.wikidata.org/wiki/Q130851', 0.1431)
# ('Montferrat', 'GPE', 'Q19868', 'https://www.wikidata.org/wiki/Q19868', 0.1245)
# ('Two', 'CARDINAL', 'Q48837', 'https://www.wikidata.org/wiki/Q48837', 0.0826)
# ('Conrade', 'ORG', 'Q130851', 'https://www.wikidata.org/wiki/Q130851', 0.1431)
# ('Sidon', 'GPE', 'Q163490', 'https://www.wikidata.org/wiki/Q163490', 0.3839)
# ('Palestine', 'GPE', 'Q23792', 'https://www.wikidata.org/wiki/Q23792', 0.2439)
# ('Richard', 'PERSON', None, None, None)
# ('Conrade', 'ORG', 'Q130851', 'https://www.wikidata.org/wiki/Q130851', 0.1431)
# ('Conrade', 'PERSON', 'Q130851', 'https://www.wikidata.org/wiki/Q130851', 0.1431)
# ('Richard', 'PERSON', None, None, None)
# ('Europe', 'LOC', 'Q46', 'https://www.wikidata.org/wiki/Q46', 0.4021)
# ('France', 'GPE', 'Q142', 'https://www.wikidata.org/wiki/Q142', 0.3523)
# ('i.', 'PERSON', None, None, None)
# ('71', 'CARDINAL', 'Q586651', 'https://www.wikidata.org/wiki/Q586651', 0.0826)
# ('Vinisauf', 'ORG', None, None, None)
# ('391', 'CARDINAL', 'Q6526762', 'https://www.wikidata.org/wiki/Q6526762', 0.0827)
# ('1243', 'DATE', 'Q5438', 'https://www.wikidata.org/wiki/Q5438', 0.0926)
# ('i.p', 'GPE', None, None, None)
# ('Trivet', 'ORG', 'Q2569925', 'https://www.wikidata.org/wiki/Q2569925', 0.1674)
# ('124', 'CARDINAL', 'Q494744', 'https://www.wikidata.org/wiki/Q494744', 0.0826)
# ('W. Hem', 'PERSON', None, None, None)
# ('544', 'CARDINAL', 'Q31012', 'https://www.wikidata.org/wiki/Q31012', 0.0892)
# ('680', 'CARDINAL', 'Q23453', 'https://www.wikidata.org/wiki/Q23453', 0.0827)
# ('2', 'CARDINAL', 'Q200', 'https://www.wikidata.org/wiki/Q200', 0.0826)
# ('20', 'CARDINAL', 'Q407881', 'https://www.wikidata.org/wiki/Q407881', 0.0826)
# ('1192', 'DATE', 'Q19739', 'https://www.wikidata.org/wiki/Q19739', 0.1473)
# ('Richard', 'PERSON', None, None, None)
# ('Montfcrrat', 'ORG', None, None, None)
# ('Europe', 'LOC', 'Q46', 'https://www.wikidata.org/wiki/Q46', 0.4021)
# ('Christendom', 'ORG', 'Q641707', 'https://www.wikidata.org/wiki/Q641707', 0.617)
# ('Richard', 'PERSON', None, None, None)
# ('Palestine', 'GPE', 'Q23792', 'https://www.wikidata.org/wiki/Q23792', 0.5002)
# ('Christian', 'NORP', 'Q106039', 'https://www.wikidata.org/wiki/Q106039', 0.111)
# ('Jeru', 'GPE', 'Q2919121', 'https://www.wikidata.org/wiki/Q2919121', 0.1036)
# ('Saladin', 'PERSON', 'Q8581', 'https://www.wikidata.org/wiki/Q8581', 0.682)
# ('300,000', 'CARDINAL', 'Q625817', 'https://www.wikidata.org/wiki/Q625817', 0.1469)
# ('va', 'GPE', 'Q1370', 'https://www.wikidata.org/wiki/Q1370', 0.0826)
# ('Christians', 'NORP', 'Q106039', 'https://www.wikidata.org/wiki/Q106039', 0.111)
# ('Burgundy', 'PERSON', 'Q1173', 'https://www.wikidata.org/wiki/Q1173', 0.4895)
# ('the beginning of the day', 'DATE', None, None, None)
# ('Richard', 'PERSON', None, None, None)
# ('two', 'CARDINAL', 'Q200', 'https://www.wikidata.org/wiki/Q200', 0.0826)
# ('Saracens', 'NORP', 'Q105763', 'https://www.wikidata.org/wiki/Q105763', 0.5048)
# ('forty thousand', 'CARDINAL', None, None, None)
# ('the field.1 Ascalon', 'WORK_OF_ART', None, None, None)
# ('Christians', 'NORP', 'Q106039', 'https://www.wikidata.org/wiki/Q106039', 0.111)
# ('k W. Heming', 'PERSON', None, None, None)
# ('532', 'CARDINAL', 'Q30393', 'https://www.wikidata.org/wiki/Q30393', 0.0827)
# ('Brompton', 'GPE', 'Q2926028', 'https://www.wikidata.org/wiki/Q2926028', 0.1008)
# ('1245', 'CARDINAL', 'Q5440', 'https://www.wikidata.org/wiki/Q5440', 0.0889)
# ('Hoveden', 'PERSON', 'Q1231843', 'https://www.wikidata.org/wiki/Q1231843', 0.3471)
# ('698', 'CARDINAL', 'Q23491', 'https://www.wikidata.org/wiki/Q23491', 0.0827)
# ('677', 'CARDINAL', 'Q6870807', 'https://www.wikidata.org/wiki/Q6870807', 0.0827)
# ('66^.', 'CARDINAL', None, None, None)
# ('1214', 'DATE', 'Q5358', 'https://www.wikidata.org/wiki/Q5358', 0.0897)
# ('RICHARD I. 21', 'PERSON', None, None, None)
# ('Richard', 'PERSON', None, None, None)
# ('Jerusalem', 'GPE', 'Q1218', 'https://www.wikidata.org/wiki/Q1218', 0.3639)
# ('ii<>2', 'NORP', None, None, None)
# ('first', 'ORDINAL', None, None, None)
# ('dis ease', 'ORG', None, None, None)
# ('England', 'GPE', 'Q21', 'https://www.wikidata.org/wiki/Q21', 0.2171)
# ('Europe', 'LOC', 'Q46', 'https://www.wikidata.org/wiki/Q46', 0.4021)
# ('Germans', 'NORP', 'Q42884', 'https://www.wikidata.org/wiki/Q42884', 0.1136)
# ('Italians', 'NORP', 'Q50001', 'https://www.wikidata.org/wiki/Q50001', 0.1182)
# ('French', 'NORP', 'Q142', 'https://www.wikidata.org/wiki/Q142', 0.1047)
# ('Burgundy', 'PERSON', 'Q1173', 'https://www.wikidata.org/wiki/Q1173', 0.1795)
# ('Philip', 'PERSON', 'Q43675', 'https://www.wikidata.org/wiki/Q43675', 0.0826)
# ('Rich', 'PERSON', 'Q3430427', 'https://www.wikidata.org/wiki/Q3430427', 0.0826)
# ('Chris', 'PERSON', 'Q925989', 'https://www.wikidata.org/wiki/Q925989', 0.0826)
# ('Saladin', 'PERSON', 'Q8581', 'https://www.wikidata.org/wiki/Q8581', 0.682)
# ('Richard', 'PERSON', None, None, None)
# ('Acre', 'GPE', 'Q126084', 'https://www.wikidata.org/wiki/Q126084', 0.5084)
# ('Joppa', 'GPE', 'Q180294', 'https://www.wikidata.org/wiki/Q180294', 0.4919)
# ('Palestine', 'GPE', 'Q23792', 'https://www.wikidata.org/wiki/Q23792', 0.4898)
# ('Christians', 'NORP', 'Q106039', 'https://www.wikidata.org/wiki/Q106039', 0.111)
# ('Je', 'GPE', 'Q134100', 'https://www.wikidata.org/wiki/Q134100', 0.0824)
# ('three years', 'DATE', 'Q238809', 'https://www.wikidata.org/wiki/Q238809', 0.1355)
# ('three months', 'DATE', 'Q191891', 'https://www.wikidata.org/wiki/Q191891', 0.1469)
# ('three weeks', 'DATE', 'Q3990877', 'https://www.wikidata.org/wiki/Q3990877', 0.1871)
# ('three days', 'DATE', 'Q7768975', 'https://www.wikidata.org/wiki/Q7768975', 0.1469)
# ('three hours', 'TIME', 'Q7797530', 'https://www.wikidata.org/wiki/Q7797530', 0.4381)
# ('Europeans', 'NORP', 'Q1464982', 'https://www.wikidata.org/wiki/Q1464982', 0.0826)
# ('Vinisauf', 'PERSON', None, None, None)
# ('380', 'CARDINAL', 'Q34157', 'https://www.wikidata.org/wiki/Q34157', 0.0826)
