# %% [markdown]
# # (Calling) Functions

# %% [markdown]
# ![call](https://i.giphy.com/media/v1.Y2lkPTc5MGI3NjExNmxsM3M5dmlheXo5M3hyajhnOXFlODFsdDY0cmJsM294dHBmM3kzMCZlcD12MV9pbnRlcm5hbF9naWZfYnlfaWQmY3Q9Zw/yNnVpD7C3X9djBK911/giphy.gif)

# %% [markdown]
# Functions are how we stop repeating ourselves. So far, every time we wanted to count something we wrote the same few lines again: a variable set to zero, a loop, a condition.
#
# A function lets us name that recipe once — *count how often this word appears* — and then reuse it on one document, or on ten thousand. This is the step from writing lines of code to building a small **text analysis pipeline**.

# %% [markdown]
# ### Terminology

# %% [markdown]
# In the previous notebooks, we referred to a Python concept named **functions**.
#
# Python provides many 'in-built' functions. Usually, functions contain **round brackets** at the end of a statement.
#
# For example:

# %%
type("42")

# %% [markdown]
# In Python language, this statement means "calling a function".
#
# Many things happen in this code snippet.
# - We call a function with the **name** `type`.
# - We pass a value or variable as an **argument** (a string "42")
# - The function **returns** the type of the argument (`str`).

# %% [markdown]
# Functions usually perform an **action** on a given **input** and **return** the result of this action (not always, but let's not always complicate matters, please).
#
# Functions are small, elementary **factories**, each processing inputs and contributing materials to your software.

# %% [markdown]
# ### Built-in functions

# %% [markdown]
# Python provides many built-in functions for strings.
#
# **Exercise**: Can you describe the `len` function?

# %%
len("Hello, world!")

# %%
len("pneumonoultramicroscopicsilicovolcanoconiosis")

# %% [markdown]
# We will discuss string functions (often referred to as string methods in one the next notebooks).
#
# We can also call a function on a list of numbers.

# %%
max([1,99,2,0])

# %% [markdown]
# **Exercise**: Can you describe the `min` function? What will it return?

# %%
min([-1, .0, 4.5])

# %% [markdown]
# ### Composition and nesting
#
# An important feature is called "composition". One function call can surround another. Put differently: A function calls can be **nested**.
#
# **Exercise**: can you tell me what happens here?

# %%
word = "pneumonoultramicroscopicsilicovolcanoconiosis"
type(len(word))

# %% [markdown]
# ## Writing functions
#
# These built-in functions are part of Python's toolkit. They are written for your convenience and serve many purposes. We will discuss some of these functions in more detail later.
#
# These built-in functions will bring you far, but often you will have to develop a **bespoke** function.
#
# Creating bespoke functions is a critical building block for designing your research!

# %% [markdown]
# ### Why?

# %% [markdown]
# **Why** write your own functions? To answer this question, let's have a look at a toy-example.
#
# Imagine you need to write a programme that checks wether your text is longer than 5 characters.

# %%
text = 'Supercalifragilisticexpialidocious'
if len(text) > 5:
    print('Yes')
else:
    print('No')

# %% [markdown]
# However, instead of using it once, you need to apply these statements to more data. To repeat this operation to two words, a simple solution would be to copy-paste the code.

# %%
text_1 = 'Supercalifragilisticexpialidocious'
if len(text_1) > 5:
    print(True)
else:
    print(False)
    
# assume you are doing more stuff here
    
text_2 = 'Yo!'
if len(text_2) > 5:
    print(True)
else:
    print(False)

# %% [markdown]
# But what if we
# - have to process thousands of words **and**
# - need to reuse this procedure elsewhere?
#
# Instead of copy-passting, a better solution is to **package** this these statements as a function.
#
# In the code cell below, we define a new function named `check_length`. It takes an argument and checks whether this text consists of more than five characters. If so, the function returns `True`, otherwise `False`.

# %%
def check_length(word):
    if len(word) > 5:
        return True
    else:
        return False

# %% [markdown]
# Now we can repeat these checks with fewer lines of code.

# %%
print(check_length('Supercalifragilisticexpialidocious'))
# you are still doing some stuff here
print(check_length('Yo'))

# %% [markdown]
# ## When to write functions?

# %% [markdown]
# With functions, you can **group and reuse a sequence of statements** (and execute them with one function call).
#
# A common example from text mining is **preprocessing**, a sequence of operations that transform inputs into a format more amenable to computational analysis. We discuss preprocessing steps in more detail later, but a simple example step could be:
#
# - Check if a text has more than 5 characters
# - if so, return the text in the lowercased form (see the `.lower()` example in session 2)
# - Otherwise, return an empty string

# %%
def preprocess_text(text):
    if len(text) > 5:
        lowercased = text.lower()
        return lowercased
    else:
        return ''

# %%
text = 'SupercalifragilisticexpialidociouS'
preprocess_text(text)

# %%
text = 'Yo!'
preprocess_text(text)

# %% [markdown]
# ### Repeating, repeat
#
#
# When you write code for a research project, you'll notice that some operations form a unit that you want to **repeat**.
#
# Wrapping them in a function will make your code more **concise** and less **error-prone** (again, this approach is much better than copy-pasting).
#
# For example, by creating a function for preprocessing text, we are sure that each incoming document will be transformed in **identically**.

# %% [markdown]
# ## How to write functions?

# %% [markdown]
# Function **definitions** follow a general syntax:
#
# ```python
# def name(parameters):
#     statements
#     return output
# ```
#
# - The **name** is used to call the function. (You can use any name except those that belong the small category of Python keywords)
# - **Parameters** comprise the information you want to pass to a function
#     - i.e. What's the input?
# - **Statements**: the sequence of statements that perform an operation
#     - i.e. What will you do with the input?
# - Functions often end with a `return` statement
#     - i.e. What to return given an input?

# %% [markdown]
# ### Parameters and arguments
#
# From [W3](https://www.w3schools.com/python/gloss_python_function_arguments.asp#:~:text=The%20terms%20parameter%20and%20argument,function%20when%20it%20is%20called.)
# > "A parameter is the variable listed inside the parentheses in the function definition. An argument is the value that are sent to the function when it is called."
#
#
# I tend to confuse these and use them interchangeably!
#
# ```def type(value):```
# - create a function with one parameter called value
#
# ```type("42")```
# - call the `type` function and pass the value "42" as the argument

# %% [markdown]
# ## Example 1: Functional regards (or: creating a greeting factory)
#
# We can write a simple function that takes a first name as input and prints a nice greeting. In normal Python, we could use the following statements.
# - We define a `first_name` variable
# - We combine the name and the greeting with a `+` operator, and save it in the `greeting_message` variable.

# %%
first_name = 'Kaspar'
greeting_message = 'Hello, ' + first_name # with the + operator we can combine or concatenate strings

# %% [markdown]
# ✏️ **1. Exercise:**
#
#
# Can you write a function
# - with the name `greeting`
# - it takes one parameter called `first_name`
# - it creates a greeting messsage of your choice (but it has to contain the `first_name`)
# - `return` the greeting message
# - try it on different names, e.g. "Clytemnestra" or "Vercingetorix"
#
# **Optional Exercise**
# - What happens if you change the `return` statement with with `print`?

# %%
# write answer here

# %% [markdown]
# ## Example 2: Computing the mean in Python
#
# Let's try to build a function that computes the average text length in Python.
#
# Imagine we collected the number of words in five documents
# ```python
# doc_lengths = [10,44,52,16,97]
# ```

# %% [markdown]
# To compute the mean we need sum all values and divide this number by number of elements.
# We can easily performs this sequence of statements using the built-in `sum` and `len` Python functions.

# %%
doc_lengths = [10,44,52,16,97]    # the number of words in each of five documents

lengths_sum = sum(doc_lengths)
print(lengths_sum)

# %%
number_of_documents = len(doc_lengths)
print(number_of_documents)

# %%
mean_length = lengths_sum / number_of_documents
print(mean_length)

# %% [markdown]
# So the five documents we collected are, on average, almost 44 words long. Note what just happened: we counted (the words in each document), and then we summarised those counts into a single number. Most text analysis is some version of this.

# %% [markdown]
# ✏️ **2. Exercise:**
#
# In Python code you can compute the mean by combining the already existing `sum` and `len` functions.
# ```python
# sum(doc_lengths)/len(doc_lengths)
# ```
#
# Can you write a function
# - with the name `compute_mean`
# - it takes one argument called `list_of_numbers`
# - it computes the mean and saves it in a variable `mean`
# - returns the results of this operation
# - try it on different examples, e.g. `[1,3,4]` or `[3,0,9,12]`

# %% [markdown]
# A good starting point for defining a function is to think how to convert the process of doing an operation "manually", in a series of defined steps.Let's see an example below

# %%
# write answer here

# %% [markdown]
# ## Functions with Multiple Parameters

# %% [markdown]
# Returning the example of the `check_length` function. We used five as the cut-off, but what if we want to set the bar a bit higher, to ten for example? Of course, you could write two separate functions as shown below:

# %%
def check_length_min_five(word):
    if len(word) > 5:
        return True
    else:
        return False
    
def check_length_min_ten(word):
    if len(word) > 10:
        return True
    else:
        return False

# %% [markdown]
# But this is not very elegant, as we are needlessly duplicating code. Instead we could create a more generic function with **two parameters**: one for the input text (`word`) and one that determines the threshold value (`min_length`).

# %%
def check_length(word, min_length):
    if len(word) > min_length:
        return True
    else:
        return False

# %%
check_length('Hello', 2)

# %%
check_length('Hello', 10)

# %% [markdown]
# ✏️ **3. Exercise:**
#
# Write a function (feel free to chose a name to your liking)
# - that takes two integer arguments `x` and `y`
# - if `x >= y` it returns `x - y`
# - else it return `x + y`

# %%
# write answer here

# %% [markdown]
# ✏️ **4. Exercise:**
#
# In the previous notebook we counted how often a word appeared in a list by writing a counter and a loop by hand. That is exactly the kind of process worth packaging as a function.
#
# Write a function
# - with the name `count_occurrences`
# - that takes two parameters: `words` (a list of words) and `target` (the word we are looking for)
# - it goes through the list and counts how many times `target` appears
# - it returns the count
# - try it on the list below, looking for `"times"` and then for `"the"`

# %%
words = ["it", "was", "the", "best", "of", "times", "it", "was", "the", "worst", "of", "times"]

# write answer here

# %% [markdown]
# ## Summary
#
# Remember: function avoid duplication (in the sense of copy-pasting), makes code more concise by enabling efficient reuse through 'function calling'. Once you defined a specific operation (for instance `compute_mean`) you'll be able to reuse it over and over, whenever needed.
#
# Function enable you to compose code based on clear and meaningful units (i.e. factories) that contribute to larger and more complex piece of software.
#
# However, there are two problems with functions:
# 1. **functions need proper documention:** otherwise they will be difficult to read (even by you in a few weeks!) and understand how unites fit within the bigger pictures of your programme
# 2. **they can have bugs too:** So you need to be careful and check if they are correct (at a semantic level).

# %% [markdown]
# # Fin.

# %% [markdown]
# ## Advanced: Documenting functions
#
# A Python docstring is a documentation string. When you call the built-in help() function on a Python function for instance, you see its documentation. This documentation is specified by the docstring at the beginning of the definition.

# %%
### this description is the way a function is documented, so others can quickly understand how to use it
help(sum)

# %%
def compute_mean(numbers):
    """ compute the mean, given a list of numbers """
    mean = sum(numbers)/len(numbers)
    return mean

# %% [markdown]
# Ok this looks better, but still the input / output and operation are hard to read. A way of documenting function is following the [Google style for docstring](https://google.github.io/styleguide/pyguide.html). Here's an example

# %%
def compute_mean(numbers):
    """ compute the mean, given a list of numbers 
    
    Args:
        numbers: List of integers
    
    Returns:
        The mean of the values contained in the list
    """
    mean = sum(numbers)/len(numbers)
    return mean

help(compute_mean)

# %% [markdown]
# Additionally, you can write the types of arguments and return values

# %%
def compute_mean(numbers:list)-> float:
    """ compute the mean, given a list of numbers 
    
    Args:
        numbers: List of integers
    
    Returns:
        The mean of the values contained in the list
    """
    mean = sum(numbers)/len(numbers)
    return mean

help(compute_mean)

# %% [markdown]
# Finally, you can make the variable names more clear or even breaking down each step to make it more readable

# %%
def compute_mean(list_of_numbers:list)-> float:
    """ compute the mean, given a list of numbers 
    
    Args:
        numbers: List of numbers (either integers or floats)
    
    Returns:
        The mean of the values contained in the list
    """
    sum_list = sum(list_of_numbers)
    length_list = len(list_of_numbers)
    mean = sum_list / length_list
    return mean

# %%
# to use the function

list_a = [1,4,5,6,7]
list_b = [10,124,65,86,7,98,6,54,112,13,87]

mean_a = compute_mean(list_a)
mean_b = compute_mean(list_b)

print (mean_a)
print (mean_b)

# %% [markdown]
# ## Advanced: Testing Functions
#
# Functions are really useful tools when writing code. They allow your scripts to be more concise and modular. However, functions can easily add bugs to your code. Let's see the following example

# %%
def compute_mean(list_of_numbers:list)-> float:
    """ compute the mean, given a list of numbers 
    
    Args:
        numbers: List of integers
    
    Returns:
        The mean of the values contained in the list
    """
    sum_list = sum(list_of_numbers)
    length_list = len(list_of_numbers)
    mean = sum_list / length_list
    return length_list

mean_a = compute_mean(list_a)
print(mean_a)

# %% [markdown]
# In this example the function is well documented and as expected returns a number, however by mistake we are returning the length of the list instead of the computed mean. Bugs like this one are very easy to make and hard to spot when you have a fairly complex pipeline.
#
# To make sure the functions work correctly often people test them quickly after having implemented or spot errors by looking at the final output of the code. However both these approaches add additional issues.
#
# So, what are best practices in testing your code?
#
# A good starting point is to define some specific cases where you test your function and you know what output it should give, for instance:

# %%
# In Python, the assert statement is used to continue the execute if the given condition evaluates to True. 
# If the assert condition evaluates to False, then it raises the AssertionError exception with the specified error message.

assert compute_mean([1,4,5,6,7]) == 4.6,'The mean is not correct'

# %% [markdown]
# Everytime you write a function, define a series of assert statements that should produce a specfic outcome.
#
# Other typical things that are important to test is that the input you are expecting is correct. For instance in our function we are expecting a list of numbers (either integers or floats)
#
# What happens if the list contains a string? or the input list is empty? or the input is not a list?
# Let's see!

# %%
compute_mean([1,4,"0.555",6,7])

# %%
compute_mean([])

# %%
compute_mean(5)

# %% [markdown]
# As you can see the code crashes for different reasons. Instead of this, we should assert that the input is what we are expecting or returning a message

# %%
def compute_mean(list_of_numbers:list)-> float:
    """ compute the mean, given a list of numbers 
    
    Args:
        numbers: List of numbers (either integers or floats)
    
    Returns:
        The mean of the values contained in the list
    """

    assert type(list_of_numbers) is list, 'The input is not a list'
    assert len(list_of_numbers) >0, 'The input list is empty'

    sum_list = sum(list_of_numbers)
    length_list = len(list_of_numbers)
    mean = sum_list / length_list
    return mean

# %% [markdown]
# ✏️ **5. Exercise:**
#
# Add an assert to test that all elements in the list are integers or float

# %%
# write answer here

# %% [markdown]
# ✏️ **6. Exercise:**
#
# Write a function that, given a list of names (containing duplicates) returns a list of names without duplicates. Make sure to include documentation and define `assert` to check the input and the correctness of the output
#
# Example of input:

# %%
names = ["Mark","Paula","Paul","Fede","Mariona","Kaspar","Paul","Thomas","Thomas","Mark","Thomas"]

# %%
# write answer here

# %% [markdown]
# ## Solutions

# %%
# 1. Exercise

# Can you write a function
# with the name `greeting`
# it takes one parameter called `first_name`
# it creates a greeting messsage of your choice (but it has to contain the `first_name`)
# `return` the greeting message
# try it on different names, e.g. "Clytemnestra" or "Vercingetorix"

def greeting(first_name):
    greeting_message = 'Hello, ' + first_name + '!'
    return greeting_message

print(greeting("Clytemnestra"))
print(greeting("Vercingetorix"))


# Optional exercise: what happens if you replace `return` with `print`?
# The function shows the message, but gives nothing back: it returns `None`,
# so we cannot store the greeting in a variable and reuse it later.

def greeting_with_print(first_name):
    print('Hello, ' + first_name + '!')

result = greeting_with_print("Vercingetorix")
print(result)

# %%
# 2. Exercise

# Can you write a function
# with the name `compute_mean`
# it takes one argument called `list_of_numbers`
# it computes the mean and saves it in a variable `mean`
# returns the results of this operation
# try it on different examples, e.g. `[1,3,4]` or `[3,0,9,12]`

def compute_mean(list_of_numbers):
    mean = sum(list_of_numbers) / len(list_of_numbers)
    return mean

print(compute_mean([1,3,4]))
print(compute_mean([3,0,9,12]))

# %%
# 3. Exercise
    
# Write a function (feel free to chose a name to your liking) 
# that takes two integer arguments `x` and `y`
# if `x >= y` it returns `x - y`
# else it return `x + y`

def blabla(x,y):
    if x >= y:
        return x - y
    return x + y

def blabla2(x,y):
    result = None
    if x >= y:
        result = x - y
    else:
        result = x + y
    return result

print(blabla(1,2), blabla2(1,2))
print(blabla(1,1), blabla2(1,1))
print(blabla(3,2), blabla2(3,2))

# %%
# 4. Exercise

# Write a function
# with the name `count_occurrences`
# that takes two parameters: `words` (a list of words) and `target` (the word we are looking for)
# it goes through the list and counts how many times `target` appears
# it returns the count

def count_occurrences(words, target):
    counter = 0
    for word in words:
        if word == target:
            counter = counter + 1
    return counter

words = ["it", "was", "the", "best", "of", "times", "it", "was", "the", "worst", "of", "times"]

print(count_occurrences(words, "times"))
print(count_occurrences(words, "the"))
print(count_occurrences(words, "Oxford"))

# %%
# 5. Exercise

# Add an assert to test that all elements in the list are integers or float

def compute_mean(list_of_numbers:list)-> float:
    """ compute the mean, given a list of numbers 
    
    Args:
        list_of_numbers: List of numbers (either integers or floats)
    
    Returns:
        The mean of the values contained in the list
    """

    assert type(list_of_numbers) is list, 'The input is not a list'
    assert len(list_of_numbers) > 0, 'The input list is empty'
    for element in list_of_numbers:
        assert type(element) is int or type(element) is float, 'The list contains something that is not a number: ' + str(element)

    sum_list = sum(list_of_numbers)
    length_list = len(list_of_numbers)
    mean = sum_list / length_list
    return mean

print(compute_mean([1,4,5,6,7]))

# Now the function stops with a clear message instead of crashing somewhere else.
# Uncomment the line below to see it:
# print(compute_mean([1,4,"0.555",6,7]))

# %%
# 6. Exercise

# Write a function that, given a list of names (containing duplicates) returns a
# list of names without duplicates. Make sure to include documentation and define
# `assert` to check the input and the correctness of the output

def remove_duplicates(list_of_names:list)-> list:
    """ remove the duplicates from a list of names, keeping the original order

    Args:
        list_of_names: List of names (strings), possibly with repetitions

    Returns:
        A list in which each name appears only once
    """

    assert type(list_of_names) is list, 'The input is not a list'

    unique_names = []
    for name in list_of_names:
        if name not in unique_names:      # only keep the name if we haven't seen it before
            unique_names.append(name)     # `.append()` adds an element at the end of a list

    # checking the output: no more elements than we started with, and no repetitions left
    assert len(unique_names) <= len(list_of_names), 'The output is longer than the input'
    for name in unique_names:
        assert unique_names.count(name) == 1, 'There are still duplicates in the output'

    return unique_names

names = ["Mark","Paula","Paul","Fede","Mariona","Kaspar","Paul","Thomas","Thomas","Mark","Thomas"]

print(remove_duplicates(names))
print(len(names), 'names in,', len(remove_duplicates(names)), 'names out')

# In session 2 we will see a shortcut for this, using a `set`: a data type that
# cannot contain duplicates by definition.
