# %% [markdown]
# # Running LLMs on your laptop
#
# Large language models are huge models that require a large amount of computational resources not only for training but also for generating an output.
#
# ![](images/llama3-meme.png)
#
# ## So, how do people manage to run them on their laptops?
#
# ### Quantization
#
# - Reduces model size by converting weights from float32 to lower precision (e.g., int8).
# - Improves inference speed and reduces memory footprint.
# - Trade-off: May slightly impact model accuracy.
#
# ### Model Pruning
#
# - Eliminates redundant or less important neurons/weights.
# - Results in a sparser model that requires less computation.
# - Trade-off: Can lead to a decrease in model performance if overly aggressive.
#
# ### Distillation
#
# - Creates a smaller, more efficient model (student) that mimics a larger model (teacher).
# - Retains much of the original model’s performance with fewer parameters.
# - Useful for deploying models on resource-constrained devices.
#
# ### Model Compression
#
# - Apply methods such as weight sharing and low-rank factorization to compress the model.
# - Helps in fitting larger models into limited laptop storage and memory.

# %% [markdown]
# ## Ollama
#
# ![](images/ollama.png)

# %% [markdown]
# ## Step by step process
# Download, install and starts [Ollama](https://ollama.com/)
#
# Run `ollama run gemma2:2b`
#
# Start chatting with a [Gemma model](https://ai.google.dev/gemma) that runs directly on your laptop!
#
# Then you can explore many more models [here](https://ollama.com/library)!

# %% [markdown]
# # If you want to interact with Ollama from Python
#
# Make sure Ollama is running on your laptop, then:

# %%
import ollama
from IPython.display import Markdown, display

def get_response_from_model(prompt, model):
    response = ollama.generate(model=model, prompt=prompt)
    return response['response']

# Define the prompt and model
prompt = "Is Ollama the best tool I have ever encountered?"
model = "gemma2:2b"

# Get the response from the model
response = get_response_from_model(prompt, model)

# Display the Markdown
display(Markdown(response))
# Out:
# Whether or not Ollama is "the best" tool you've ever encountered depends entirely on your needs and what you want to achieve!
#
# **Here's why it might be considered great:**
#
# * **Open-source and accessible:** It's free to use, adapt, and distribute. This makes it readily available for developers and users alike.
# * **Fine-tuned language model:**  Ollama has been trained on a massive dataset, which allows it to understand and generate human-like text with impressive accuracy.
# * **Customizable & flexible:** It can be fine-tuned and adapted for specific tasks like writing stories, translating languages, or generating code.
#
# **However, there are some things to consider:**
#
# * **Performance limitations:**  It might not always outperform proprietary models, especially on complex tasks requiring advanced reasoning.
# * **Resource demands:** Running Ollama locally can be resource-intensive depending on its size and the task you're trying to accomplish.
# * **Not a replacement for human expertise:**  Like all AI tools, Ollama is a tool that requires understanding of context and ethical considerations for optimal use.
#
# **Ultimately, "best" depends on your individual priorities.** If you value open-source access, flexibility, and are willing to put in the effort for customization, Ollama could be an excellent choice. But if high performance, effortless integration with other tools, or a specific set of features are critical, other options might be better suited.
#
#
# **Before deciding, ask yourself:**
#
# * What's my primary use case?
# * What kind of resources and technical expertise do I have?
# * Are there specific functionalities I need that Ollama offers?
#
#
#
# Do some research and compare it to other tools in your field to make an informed decision! 😄
