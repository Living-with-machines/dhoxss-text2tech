# %% [markdown]
# # Topic modelling: finding themes nobody labelled

# %% [markdown]
# 📌 **Additional material.** Topic modelling is the *unsupervised* counterpart to the classifier you trained in notebook 3c: the same bag-of-words matrix, but with **no labels** to learn from. The model groups words that tend to occur together, and leaves you to work out what the groups mean.

# %% [markdown]
# ## Two ways of finding topics
#
# Suppose you have ten thousand pages of nineteenth-century print and you want to know what they are *about*. There are two situations you can be in:
#
# 1. **you know which topics you are looking for** — you have a list of categories, and some examples of each. That is *classification*, and it is what we did already.
# 2. **you don't know which topics you are looking for** — you want the collection to tell you. That is *topic modelling*, and it is what this notebook is about.
#
# The second case is the more common one when you first meet an archive. Nothing below is a new representation: we are going straight back to the document-term matrix from notebook 3c.
#
# | we need to... | and we already know |
# |---|---|
# | turn documents into word counts | `CountVectorizer` (notebook 3c) |
# | ignore words that are everywhere | `stop_words`, `max_df`, `min_df` (notebook 3c) |
# | rank things and take the top *n* | `sorted()` and `argsort()` (notebooks 2g, 3c) |
# | find the groups | `LatentDirichletAllocation` — the one new thing here |

# %% [markdown]
# ## What do we mean by a "topic"?
#
# Two definitions, and the difference between them matters:
#
# 1. a group of words that tend to appear in **the same context**;
# 2. a **hidden structure** that determines how words appear in the corpus.
#
# The first is what you can *see* — words co-occurring. The second is what you are *assuming* when you use a topic model.
#
# ![lda](https://raw.githubusercontent.com/Living-with-machines/dhoxss-text2tech/refs/heads/main/Sessions/images/lda.png)
#
# The assumption, spelled out, is a little story about how the text got written: every document is a **mixture of topics** (this page is 70% seafaring, 20% weather, 10% commerce), and every topic is a **distribution over words** (the seafaring topic uses *ship*, *captain*, *sail* often, and *honey* almost never). Writing a document means picking a topic, then picking a word from it, over and over.
#
# That story is obviously not how anybody writes. But if we pretend it is, we can run it backwards: given the documents, work out which topics and mixtures would most plausibly have produced them. That is the whole idea.

# %% [markdown]
# ## How do we get these topics?
#
# There are several methods:
#
# - Latent Semantic Analysis
# - Probabilistic Latent Semantic Analysis
# - **Latent Dirichlet Allocation (LDA)** ← the one we will use, and by far the most widely adopted
#
# LDA has been popular in digital humanities for corpus exploration because it is flexible: it works on any language for which you have a tokenizer, and it needs almost no decisions from you. You "just" have to choose the number of topics in advance — and we will see at the end that this "just" is doing a lot of work.
#
# [Slides to go through together](https://docs.google.com/presentation/d/1u5Fs1C6vwdfsv93H-iX3c4jkwyjgijxShsUjoGZPwcc/edit?usp=sharing) (starting from slide 15)

# %% [markdown]
# ## The corpus
#
# We are using a sample of digitised books created by the British Library in partnership with Microsoft — the same collection you met in notebooks 3b and 3c. To find out more, see [this blog post](https://blogs.bl.uk/digital-scholarship/2022/04/making-british-library-collections-even-more-accessible.html).

# %%
# On Colab, install the visualisation library we use later on.
# Locally you can skip this if pyLDAvis is already in your environment.
# !pip install -q pyldavis

# %%
import pandas as pd

books = pd.read_csv("https://raw.githubusercontent.com/Living-with-machines/dhoxss-text2tech/main/Sessions/data/bl_books_sample.csv")

print(books.shape)
books[["record_id", "date", "title", "Language_1"]].head(3)

# %% [markdown]
# Let's look at what one "document" actually contains.

# %%
print(books["text"].iloc[6000][:600])

# %% [markdown]
# ### ⚠️ Read the corpus before you model it
#
# That is not a book — it is a **page**. And this matters enormously for what follows, so it is worth a minute of looking:

# %%
print("rows in the table :", len(books))
print("distinct books    :", books["record_id"].nunique())
print("published between :", books["date"].min()[:4], "and", books["date"].max()[:4])
print()
print(books["Language_1"].value_counts())

# %% [markdown]
# So our 10,000 "documents" are 10,000 **pages** drawn from just **35 books**, all published between 1800 and 1809, and not all of them in English.
#
# That is a small number of books, and we can simply list them — which puts us in an unusually lucky position for an unsupervised method. Normally topic modelling is used precisely because you *cannot* read the collection. Here we can, which means we will be able to **check the model's answers** rather than admire them.

# %%
by_book = books.groupby("record_id").agg(
    pages=("text", "size"),
    language=("Language_1", "first"),
    title=("title", "first"),
)

by_book.sort_values("pages", ascending=False).head(15)

# %% [markdown]
# ## Step 1: back to the document-term matrix
#
# Exactly as in notebook 3c: every document becomes a row of word counts, every word in the vocabulary a column.

# %%
from sklearn.feature_extraction.text import CountVectorizer

vectorizer = CountVectorizer(stop_words="english", max_df=0.5, min_df=20)
dtm = vectorizer.fit_transform(books["text"])

print("shape of the document-term matrix:", dtm.shape)
print("a slice of the vocabulary:")
print(list(vectorizer.get_feature_names_out()[1500:1530]))

# %% [markdown]
# The three filtering arguments are the same ones we tuned for the classifier, and they matter more here than they did there, because there are no labels to rescue a bad vocabulary:
#
# * **`stop_words="english"`** — drop *the*, *of*, *and*... They occur on nearly every page, so they would show up in every single topic and tell us nothing.
# * **`max_df=0.5`** — also drop anything appearing on more than half the pages, including corpus-specific words that the stop word list has never heard of.
# * **`min_df=20`** — drop anything appearing on fewer than 20 pages. In OCR'd text this is doing more work than you might think: it removes the long tail of scanning errors that occur once and never again.
#
# ⚠️ Look at that vocabulary slice, though, and then at the start of it (`[:30]`, if you are curious): 312 of our 8,257 "words" are pure numbers — page numbers and dates, which survive every filter above because they really do occur on hundreds of pages. And the OCR long-s problem is in there too: `fhould` and `fhow` sit in the vocabulary as separate words from `should` and `show`. Neither is fatal, but both are the kind of thing you want to have looked at before you interpret a topic. `token_pattern` (notebook 3c) is where you would exclude the numbers.
#
# ### ⚠️ Counts here, not TF-IDF
#
# In notebook 3c we moved from `CountVectorizer` to `TfidfVectorizer` and things got better. Here we deliberately stay with plain counts.
#
# The reason is the little story from earlier. LDA is a model of **how often each word was drawn from each topic** — it expects whole numbers of word occurrences. A TF-IDF value of 0.037 is not a count of anything, so feeding it to LDA means the model's arithmetic no longer corresponds to its own assumptions. It will still run and still return topics — which is why you will see it done — but you have quietly stopped doing the thing the method is defined to do.
#
# The rarity weighting that TF-IDF gave us is not lost, incidentally: `stop_words`, `max_df` and `min_df` are already removing the words that were being down-weighted.

# %% [markdown]
# ## Step 2: fitting the model
#
# One decision to make first: **how many topics?** We will ask for 10 to start with, and come back to that choice at the end.

# %%
from sklearn.decomposition import LatentDirichletAllocation

lda = LatentDirichletAllocation(n_components=10, random_state=0)
lda.fit(dtm)

print("topics x vocabulary:", lda.components_.shape)

# %% [markdown]
# ⚠️ This takes a little while — around 15 seconds — because unlike the classifiers in 3c, the model has to iterate over the whole collection several times, guessing topic assignments and refining them.
#
# Note `random_state=0`. LDA starts from a random guess, so **the same data can give you different topics on different runs**. Fixing the random state makes this notebook reproducible; it does not make the topics any more true. (Hold on to that thought — it comes back when we talk about evaluation.)

# %% [markdown]
# ## Step 3: reading the topics
#
# `lda.components_` is a table of topics × vocabulary: for every topic, how strongly each word belongs to it. To describe a topic we take its highest-weighted words — the same `argsort()` move we used to read the SVM's weights in notebook 3c.

# %%
import numpy as np


def top_words(model, vectorizer, n_words=10):
    """ the most prominent words of every topic in a fitted topic model

    Args:
        model: a fitted LatentDirichletAllocation
        vectorizer: the vectorizer whose matrix it was fitted on
        n_words: how many words to keep per topic

    Returns:
        A dictionary of topic number -> list of words, best first
    """
    vocabulary = np.array(vectorizer.get_feature_names_out())
    topics = dict()

    for topic_id, weights in enumerate(model.components_):
        most_prominent = np.argsort(weights)[::-1][:n_words]
        topics[topic_id] = list(vocabulary[most_prominent])

    return topics


def print_topics(topics):
    """ print a dictionary of topics, one line each """
    for topic_id, words in topics.items():
        print(f"topic {topic_id:2d}:", " ".join(words))


topics = top_words(lda, vectorizer)
print_topics(topics)

# %% [markdown]
# ### What did it find?
#
# Look at those topics before reading on.
#
# Several of them are not themes at all — they are **languages**. One topic is German (*von*, *der*, *und*, *stadt*), one is French (*les*, *et*, *la*, *que*), one is Italian (*di*, *che*, *la*, *il*).
#
# This should look familiar. It is exactly the trap from Exercise 3 of notebook 3c, where the genre classifier learned that Danish function words meant "non-fiction". The same property of the same collection surfaces here, just without a label to hide behind: the strongest signal separating documents in this corpus is which *language* they are in, and an unsupervised method goes straight for the strongest signal available.
#
# ⚠️ This is worth sitting with, because it is the characteristic failure of unsupervised methods. The model was never going to tell us the languages were uninteresting. It found a real and very solid division in the data, and it is our job — not its — to know that it is not the division we asked about.

# %% [markdown]
# ### ✏️ Exercise 1
#
# Fix it: keep only the **English** pages, and fit the model again.
#
# Suggested steps:
# * filter `books` down to the rows where `Language_1` is `"English"`, and call it `english`
# * build a new `CountVectorizer` with the same settings, and fit it on `english["text"]`
# * fit a new `LatentDirichletAllocation` — ask for 15 topics this time, now that we are not spending three of them on languages
# * print the topics with `print_topics(top_words(...))`
#
# Do the topics now look like subject matter?

# %%
# Type your code here:

# %% [markdown]
# ## The English-only model
#
# Here is that model, which we will use for the rest of the notebook.

# %%
english = books[books["Language_1"] == "English"].reset_index(drop=True)
print("english pages:", len(english))

english_vectorizer = CountVectorizer(stop_words="english", max_df=0.5, min_df=20)
english_dtm = english_vectorizer.fit_transform(english["text"])

english_lda = LatentDirichletAllocation(n_components=15, random_state=0)
english_lda.fit(english_dtm)

english_topics = top_words(english_lda, english_vectorizer)
print_topics(english_topics)

# %% [markdown]
# Now we are getting somewhere. Some of these read like genuine subjects: *king / england / edward / prince / earl* is clearly historical, *sea / south / nile / island* is travel or geography, *animals / fishes / fish* is natural history, *thou / thy / love / heart* is verse.
#
# But notice that we are doing something dangerous — we are **reading ten words and inventing a subject that would explain them**. Humans are extremely good at that, including when there is nothing there. Before we trust any of these labels, let's check them.

# %% [markdown]
# ## Step 4: checking the topics against the books
#
# Here is where our small, readable corpus earns its keep. `lda.transform()` gives us the other half of the model: for every page, **how much of each topic** it is made of.

# %%
page_topics = english_lda.transform(english_dtm)

print("pages x topics:", page_topics.shape)
print()
print("the topic mixture of page 7500, rounded:")
print(page_topics[7500].round(2))
print("adds up to:", page_topics[7500].sum().round(3))

# %% [markdown]
# Every row is a **mixture** that sums to 1 — this page is 52% one topic, 23% another, 15% a third, and zero for most of the rest. That is the "documents are mixtures of topics" half of the story from the beginning of the notebook.
#
# Which means we can turn the question around. Instead of asking *"what is this topic about?"* and guessing from ten words, we can ask **"which pages score highest on this topic, and which books do those pages come from?"** — and we have the titles, so we can simply read the answer.

# %%
def which_books(topic_id, n_pages=100):
    """ the books that a topic's highest-scoring pages come from

    Args:
        topic_id: which topic to look up
        n_pages: how many of the topic's top pages to look at

    Returns:
        A count of book titles among those pages, commonest first
    """
    top_pages = np.argsort(page_topics[:, topic_id])[::-1][:n_pages]
    return english.iloc[top_pages]["title"].str.slice(0, 60).value_counts()


for topic_id, words in english_topics.items():
    print(f"topic {topic_id:2d}:", " ".join(words[:8]))
    for title, count in which_books(topic_id).head(2).items():
        print(f"           {count:3d} pages   {title}")
    print()

# %% [markdown]
# ### What that tells us
#
# This is the most useful cell in the notebook, because it turns interpretation into something checkable. Four different kinds of thing have come out, and only one of them is what we set out to find:
#
# **1. Topics that are really just one book.** *animals / fishes* is 100 out of 100 pages from *The History of Animals of Aristotle*. *thou / antony / steevens / cleopatra* is 100 out of 100 from *The Plays of William Shakspeare*. With 35 books and pages as documents, "which book is this page from" is a very strong pattern, and LDA finds it. Reassuring — it confirms the method works — but it is not a discovery.
#
# **2. Topics that genuinely cross books.** These are the interesting ones. *sea / south / nile / island* draws on both *Travels to Discover the Source of the Nile* and *Letters from Italy* — two different books, one shared theme of travel writing. The *thy / love / heart* topic pulls together several separate poetry collections. Nobody told the model that travel narratives resemble each other. That is a finding.
#
# **3. A topic that is pure OCR noise.** *iv / ii / iii / tw / tvv / cy* comes entirely from *A Complete Verbal Index to the Plays of Shakspeare* — a book that is nothing but columns of roman numerals and abbreviations, mangled by the scanner. The model dutifully gave it a topic.
#
# **4. A topic that is paratext.** *esq / mr / sets / rev / mrs / college* is not a subject at all: it is the **subscriber lists** printed at the front of these books, the people who paid for publication in advance. It appears across several books because they all have one.
#
# ⚠️ Topics 3 and 4 are not failures. This is one of the genuinely useful things topic modelling does: it is an excellent **diagnostic for your corpus**. It found the OCR disaster and the boilerplate front matter, and both are things you would want to know about before making any argument from this collection.

# %% [markdown]
# ## Which topics is a page made of?
#
# The same `page_topics` matrix, read the other way round: take a page and see its mixture.

# %%
def describe_page(index, n_topics=3):
    """ show a page and the topics it is mostly made of """
    print(english["title"].iloc[index][:70])
    print(repr(english["text"].iloc[index][:250]))
    print()

    for topic_id in np.argsort(page_topics[index])[::-1][:n_topics]:
        share = page_topics[index][topic_id]
        print(f"   {share:5.0%}  topic {topic_id:2d}:", " ".join(english_topics[topic_id][:6]))
    print()


describe_page(7500)
describe_page(5000)

# %% [markdown]
# ### ✏️ Exercise 2
#
# `which_books()` looked at the *titles* of a topic's top pages. Write a function that prints the actual **text** of the two or three pages that score highest on a given topic.
#
# Suggested steps:
# * use `np.argsort(page_topics[:, topic_id])[::-1]` to rank the pages, as `which_books()` does
# * for the first few, print the topic share, the title, and the first 300 characters of the text
#
# Then use it on a topic you thought you understood, and one you did not. Does reading the pages confirm the label you gave the topic from its ten words?

# %%
# Type your code here:

# %% [markdown]
# ## Seeing all the topics at once
#
# `pyLDAvis` gives an interactive view of a fitted model. The left panel places the topics by how similar they are to each other, with the size of each circle showing how much of the corpus it accounts for; click a circle and the right panel shows that topic's words.
#
# The **λ slider** at the top right is the part worth knowing about. At λ=1 the bars rank words by how *frequent* they are in the topic, which tends to surface the same common words for several topics. Slide it towards 0 and words are ranked by how *distinctive* they are to this topic instead. Sliding it to about 0.6 is usually the fastest way to tell two similar-looking topics apart.

# %%
import warnings

import pyLDAvis
import pyLDAvis.lda_model

warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", category=FutureWarning)

pyLDAvis.enable_notebook()

pyLDAvis.lda_model.prepare(english_lda, english_dtm, english_vectorizer)

# %% [markdown]
# ⚠️ If the visualisation does not appear (this occasionally happens on Colab, depending on how the output frame is sandboxed), save it to a file instead and open that:
#
# ```python
# visualisation = pyLDAvis.lda_model.prepare(english_lda, english_dtm, english_vectorizer)
# pyLDAvis.save_html(visualisation, "topics.html")
# ```

# %% [markdown]
# ## How do we know the topics are any good?
#
# Topic models are useful for exploration. But if we want to use them as **evidence** in an argument, "they looked sensible to me" is not enough — especially now that we have seen how readily a topic can turn out to be an OCR artefact or a subscriber list.
#
# Some approaches, in rough order of respectability:
#
# 1. ~~Looking at them~~
# 2. ~~Cherry-picking the good ones~~
# 3. Reading the top documents of each topic — which is what `which_books()` did, and the cheapest honest thing you can do
# 4. Measuring **topic coherence**: do a topic's top words actually co-occur in the corpus more than chance?
# 5. Studying **topic stability**: refit with a different `random_state` and see whether the same topics come back. The ones that survive are the ones to trust
# 6. Using the topic mixtures as **features** in another machine learning system, and seeing whether they help
# 7. Asking people, in a controlled way — the **word intrusion task**, below
#
# ![gif](https://media3.giphy.com/media/KFiQXtO3rWxlzpjnrV/giphy.gif)

# %% [markdown]
# ### The word intrusion task
#
# A neat trick from Chang et al.'s 2009 paper *Reading Tea Leaves*. Take a topic's top words, secretly swap in one word from a **different** topic, and ask a human to spot the intruder.
#
# If the topic is coherent, the intruder sticks out and people find it easily. If the topic is mush, the intruder is invisible — because nothing in the list belongs together in the first place. It turns "is this topic meaningful?" into something you can actually measure, with a score: how often do people find the intruder?

# %%
import random


def word_intrusion(topics, n_shown=4, seed=None):
    """ build a word intrusion task from a dictionary of topics

    Args:
        topics: a dictionary of topic number -> list of words, as `top_words` returns
        n_shown: how many genuine words to show alongside the intruder
        seed: fix this to get the same puzzle every time

    Returns:
        A (words, intruder) tuple: the shuffled words, and which of them is the intruder
    """
    generator = random.Random(seed)

    topic_id = generator.choice(list(topics))
    words = list(topics[topic_id][:n_shown])

    # the intruder: a prominent word of some other topic that this topic does not use
    other_topics = [other for other in topics if other != topic_id]
    generator.shuffle(other_topics)

    intruder = None
    for other in other_topics:
        candidates = [word for word in topics[other] if word not in topics[topic_id]]
        if candidates:
            intruder = candidates[0]
            break

    if intruder is None:
        raise ValueError("the topics are too similar to build an intrusion task")

    words.append(intruder)
    generator.shuffle(words)

    return words, intruder

# %%
words, intruder = word_intrusion(english_topics, seed=5)

print("Which of these words does not belong with the others?")
print("   ", ", ".join(words))

# %% [markdown]
# Have a go before running the next cell: replace `???` with your answer.

# %%
your_guess = "???"

if your_guess == intruder:
    print("Correct — that one came from a different topic.")
else:
    print(f"Not this time: the intruder was '{intruder}'.")

# %% [markdown]
# That one is easy: four words about verse and one about the sea.
#
# Now try `seed=9`, and you will get something like *iv, ssie, iii, ii, tw*. There is no way to answer, because that is the OCR topic from the Shakespeare index — there is no theme for a word to intrude on.
#
# ⚠️ **That difference is the measurement.** The intrusion task does not tell you what a topic means; it tells you whether the topic holds together well enough for the question to be answerable. Run it over all your topics with real people, and the proportion they get right is a number you can report. A model whose topics all fail the intrusion test is not one you should be quoting in a footnote.

# %% [markdown]
# ### ✏️ Exercise 3
#
# Our topics are still full of words that carry no subject matter — *called*, *great*, *time*, *like*, *forth*. One classic way to clean this up is to keep only the **nouns**, on the grounds that they are what a text is *about*.
#
# Use spaCy (notebook 4d) to keep only the nouns of each page, then fit the model again on those.
#
# Suggested steps:
# * `import spacy` and load `en_core_web_sm` — disable `parser` and `ner`, which we do not need, to save time
# * take a `sample()` of about 2,000 pages: tagging all 8,852 would take a few minutes
# * use `nlp.pipe()` over the texts and, for each document, join the tokens where `token.pos_ == "NOUN"` back into a string
# * vectorise and fit as before (use a lower `min_df`, since the sample is smaller)
#
# Do the topics look more like subjects? What have you lost along with the verbs and adjectives?

# %%
# Type your code here:

# %% [markdown]
# ## Choosing the number of topics
#
# We asked for 10 topics, then 15, and never justified either.
#
# `n_components` is a **hyperparameter**, exactly like `k` in the k-nearest-neighbours model of notebook 3c: a setting we choose rather than something the model learns. But unlike `k` there, we have no accuracy score to tune it against — that is what "unsupervised" costs us.
#
# What changes as you move it:
#
# * **too few topics** and unrelated things get merged: travel writing and natural history end up in one lumpy topic because the model has nowhere else to put them.
# * **too many** and topics start splitting into near-duplicates, and the model begins carving up noise — you get four slightly different flavours of OCR garbage.
#
# In practice you fit several models, look at them with the tools above, and pick the one that is most useful for your question. That is an uncomfortably subjective answer, and it is the honest one. ⚠️ The useful discipline is to *report* it: a topic model with an unexplained `n_components=15` is a result nobody can evaluate.

# %% [markdown]
# ## ⚠️ When there is nothing to find
#
# One last warning, and the most important one. A topic model will *always* give you the number of topics you asked for. It has no way of telling you that your corpus does not have any.
#
# Here is the Living with Machines [atypical animacy dataset](https://bl.iro.bl.uk/concern/datasets/323177af-6081-4e93-8aaf-7932ca4a390a?locale=en): 393 short snippets of nineteenth-century text, every single one of which was selected *because* it mentions a machine.

# %%
animacy = pd.read_csv("https://raw.githubusercontent.com/Living-with-machines/dhoxss-text2tech/main/Sessions/data/animacy.tsv", sep="\t")
print(len(animacy), "snippets")
print()
print(animacy["TextSnippet"].iloc[0])

# %%
animacy_vectorizer = CountVectorizer(stop_words="english", max_df=0.5, min_df=5)
animacy_dtm = animacy_vectorizer.fit_transform(animacy["TextSnippet"])

animacy_lda = LatentDirichletAllocation(n_components=6, random_state=0)
animacy_lda.fit(animacy_dtm)

print_topics(top_words(animacy_lda, animacy_vectorizer))

# %% [markdown]
# Six topics, and every one of them is *machine, engine, machines, machinery*. Which is correct — that is what the corpus is about — and completely useless.
#
# Two things went wrong, and both are common. The corpus is **thematically homogeneous**, so there is no variation for the model to divide up; and it is **small**, 393 snippets of a few hundred characters, so there is not enough co-occurrence evidence to learn from even if there were.
#
# Nothing in the output says any of this. The model returned six topics, formatted exactly like the good ones from the British Library books. You have to know to look.

# %% [markdown]
# ## Where this goes next
#
# * **The thing that limits everything here** is the same limitation as in notebooks 2g and 3c: a bag of words. *ship* and *vessel* are separate columns with no relationship, so a topic has to learn them as two independent pieces of evidence, from scratch, out of co-occurrence. LDA works around this rather than solving it.
# * **Notebooks 4a and 4b** are the answer: word embeddings, where similar words *are* similar numbers. Modern topic modelling tools (BERTopic and friends) work by clustering embeddings rather than counting words, and need far less vocabulary tuning as a result — but they are harder to inspect than `lda.components_`, which is a real trade-off, not just a newer-is-better story.
# * **The habit to keep**, whichever method you use: never publish a topic you have not read the underlying documents for. Everything interesting in this notebook came from `which_books()`, not from the list of ten words.

# %% [markdown]
# # Solutions

# %% [markdown]
# ### ✏️ Exercise 1

# %%
english = books[books["Language_1"] == "English"].reset_index(drop=True)
print("english pages:", len(english))

english_vectorizer = CountVectorizer(stop_words="english", max_df=0.5, min_df=20)
english_dtm = english_vectorizer.fit_transform(english["text"])

english_lda = LatentDirichletAllocation(n_components=15, random_state=0)
english_lda.fit(english_dtm)

print_topics(top_words(english_lda, english_vectorizer))

# The German, French and Italian topics are gone, and the 15 topics are now spent on
# subject matter instead: history, travel, natural history, verse, farming in America.
# Note what we gave up to get here, though: 1,148 pages of French, Italian and German
# books that are now simply outside the analysis.

# %% [markdown]
# ### ✏️ Exercise 2

# %%
def read_top_pages(topic_id, n_pages=3, n_chars=300):
    """ print the pages that score highest on a topic, so we can read them """
    ranked = np.argsort(page_topics[:, topic_id])[::-1][:n_pages]

    print(f"TOPIC {topic_id}:", " ".join(english_topics[topic_id]))
    print()
    for index in ranked:
        print(f"   [{page_topics[index][topic_id]:.0%} of this page] {english['title'].iloc[index][:60]}")
        print("   ", repr(english["text"].iloc[index][:n_chars]))
        print()


read_top_pages(2)    # sea / nile / island — travel writing, and the pages confirm it
read_top_pages(12)   # esq / mr / sets / rev — reading the pages shows these are subscriber lists,
                     # which no amount of staring at the ten words would have told us

# %% [markdown]
# ### ✏️ Exercise 3

# %%
import spacy

nlp = spacy.load("en_core_web_sm", disable=["parser", "ner"])

# a sample, because tagging all 8,852 pages takes a few minutes
sample = english.sample(2000, random_state=0)

nouns_only = [
    " ".join(token.text.lower() for token in document if token.pos_ == "NOUN")
    for document in nlp.pipe(sample["text"].astype(str), batch_size=64)
]

print(nouns_only[0][:200])
print()

nouns_vectorizer = CountVectorizer(stop_words="english", max_df=0.5, min_df=10)
nouns_dtm = nouns_vectorizer.fit_transform(nouns_only)

nouns_lda = LatentDirichletAllocation(n_components=10, random_state=0)
nouns_lda.fit(nouns_dtm)

print_topics(top_words(nouns_lda, nouns_vectorizer))

# Much more subject-like: bees and honey, kingdom and army, animals and fishes,
# soil and corn and cattle, love and soul and eyes. The filler words that were
# padding out the earlier topics (called, great, forth, like) are gone.
#
# What we lost: the Shakespeare topic, which was held together by *thou*, *thy*, *fo* —
# function words and OCR errors, not nouns. Keeping only nouns is a genuine trade-off,
# not a free improvement. It also costs a POS tagger run over the whole corpus, and the
# tagger was trained on modern English, so its accuracy on OCR'd 1800s print is
# itself a source of error you are now inheriting.
